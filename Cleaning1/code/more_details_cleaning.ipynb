# %% [markdown]
# # Cleaning IMDB Movie Data
#
# In this notebook, we will engage in a comprehensive cleaning and transformation process on IMDB movie data that was initially scraped. The process involves several distinct stages:
#
# #### **Understanding the Data**
# A preliminary exploration of the dataset is carried out to identify its shape, column names, basic statistics, and characteristics. This forms the foundation for the subsequent cleaning process.
#
# #### **Cleaning Columns Part 1: Basic Information and Transformation**
# In this section, the focus is on cleaning and transforming several key columns. The steps include:
#
# - **Renaming Columns**: Ensuring consistency in column names.
# - **Standardizing Formats**: Converting columns like runtime into standardized formats.
# - **Cleaning Specific Columns**: Working on columns like sound_mix, aspect_ratio, budget, and gross_us_canada.
# - **Creating New Columns**: Adding columns like budget_estimated for enhanced analysis.
# - **Handling Country Information**: Merging and transforming data related to countries of origin.
# - **Processing Directors, Writers, and Stars**: Extracting and organizing information related to these categories.
#
# #### **Cleaning Columns Part 2: User Reviews, Unstructured Data, and Technical Details**
# Continuing the cleaning process, this section focuses on:
#
# - **Handling User and Critic Reviews**: Converting and cleaning review-related columns.
# - **Processing Unstructured Data**: Working with plot summaries, synopsis, and other text data.
# - **Cleaning Technical Details**: Managing details like color, camera, laboratory, film length, negative format, cinematographic process, and printed film format.
# - **Working with Production Companies**: Creating detailed views of production companies and their projects.
#
# #### **Mastering Data Management (MDM) Function**
# A specialized cleaning process is introduced to manage the production_companies column. We create a detailed view of individual companies, capturing the projects they've worked on, and saving this information for later use.
#
# #### **Exporting the Data**
# The cleaned data is then exported into different files, with and without reviews. This ensures that the cleaned dataset is ready for subsequent stages of analysis, such as exploratory data analysis (EDA), visualization, modeling, and insight extraction.
#
# #### **Conclusion**
# By the end of this process, our goal is to have a well-structured and cleaned dataset, free from inconsistencies and formatted to meet the project's analytical needs. This cleaned dataset forms the basis for deeper insights and more accurate modeling in the upcoming stages of the project.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Enabling nice dataframe formatting
from google.colab import data_table
data_table.enable_dataframe_formatter()

# %%
df_scraped = pd.read_csv('/content/drive/MyDrive/IMDB Project/Cleaning1/data/more_details_to_clean.csv')
# Out:
# <ipython-input-3-173d1fe0de18>:1: DtypeWarning: Columns (15,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_scraped = pd.read_csv('/content/drive/MyDrive/IMDB Project/Cleaning1/data/more_details_to_clean.csv')

# %% [markdown]
# ## Understanding the data

# %%
df_scraped
# Out:
# Warning: total number of rows (69419) exceeds max_rows (20000). Falling back to pandas display.
#           imdb_id                               title               runtime  \
# 0       tt1277953  Madagascar 3: Europe's Most Wanted  ['1h 35m', '1h 33m']
# 1       tt1690953                     Despicable Me 2            ['1h 38m']
# 2       tt1453405                 Monsters University            ['1h 44m']
# 3       tt1482459                           The Lorax            ['1h 26m']
# 4       tt1623205           Oz the Great and Powerful            ['2h 10m']
# ...           ...                                 ...                   ...
# 69414   tt8726540                   The Road to Truth            ['1h 15m']
# 69415  tt14102720                Claw 2: Blood Legacy            ['1h 31m']
# 69416   tt1821636                        The Big Idea            ['1h 38m']
# 69417  tt16293944           The Best of the Lads 2021               ['50m']
# 69418  tt11765792                 Little Green People                    []
#
#                                                sound_mix  \
# 0      ['Datasat', 'Dolby Digital', 'SDDS', 'Dolby Su...
# 1      ['Dolby Digital', 'Datasat', 'SDDS', 'Dolby At...
# 2      ['Dolby Atmos', 'Datasat', 'SDDS', 'Auro 11.1'...
# 3      ['Dolby Digital', 'Datasat', 'SDDS', 'Auro 11....
# 4      ['SDDS', 'Datasat', 'Dolby Digital', 'Dolby At...
# ...                                                  ...
# 69414                                                 []
# 69415                                                 []
# 69416                                                 []
# 69417                                                 []
# 69418                                                 []
#
#                                aspect_ratio                    budget  \
# 0      ['1.78 : 1', '1.85 : 1', '1.85 : 1']  $145,000,000 (estimated)
# 1      ['1.85 : 1', '1.91 : 1', '2.35 : 1']   $76,000,000 (estimated)
# 2                              ['1.85 : 1']  $200,000,000 (estimated)
# 3                              ['1.85 : 1']   $70,000,000 (estimated)
# 4                  ['1.33 : 1', '2.39 : 1']  $215,000,000 (estimated)
# ...                                     ...                       ...
# 69414                                    []       $50,000 (estimated)
# 69415                                    []        $1,500 (estimated)
# 69416                                    []                       NaN
# 69417                           ['16:9 HD']                       NaN
# 69418                                    []        $6,000 (estimated)
#
#        gross_us_canada  opening_weekend_us_canada  gross_worldwide  \
# 0         $216,391,482  $60,316,738, Jun 10, 2012     $746,921,274
# 1         $368,065,385   $83,517,315, Jul 7, 2013     $970,766,005
# 2         $268,492,764  $82,429,469, Jun 23, 2013     $743,559,645
# 3         $214,373,500   $70,217,070, Mar 4, 2012     $349,183,316
# 4         $234,911,825  $79,110,453, Mar 10, 2013     $493,311,825
# ...                ...                        ...              ...
# 69414              NaN                 None, None              NaN
# 69415              NaN                 None, None              NaN
# 69416              NaN                 None, None              NaN
# 69417              NaN                 None, None              NaN
# 69418              NaN                 None, None              NaN
#
#                                                  writers  ...  \
# 0                                                     []  ...
# 1      ['Cinco Paul', 'Ken Daurio', 'Cinco Paul', 'Ke...  ...
# 2                                                     []  ...
# 3      ['Dr. Seuss', 'Cinco Paul', 'Ken Daurio', 'Dr....  ...
# 4                                                     []  ...
# ...                                                  ...  ...
# 69414  ['Sharon Reeves Battle', 'Bilal Islam', 'Karen...  ...
# 69415  ['Michelle Carmen Gomez', 'David Palmieri', 'M...  ...
# 69416                                                 []  ...
# 69417  ['George Grozier', 'Jack Vickers', 'George Gro...  ...
# 69418  ['Tyler Cheman', 'Kristen Skeet', 'Tyler Chema...  ...
#
#                                         reviewer_ratings  \
# 0      [{'reviewer': 'DICK STEEL', 'rating': '8'}, {'...
# 1      [{'reviewer': 'claudio_carvalho', 'rating': '7...
# 2      [{'reviewer': 'claudio_carvalho', 'rating': '8...
# 3      [{'reviewer': 'pawanpunjabithewriter', 'rating...
# 4      [{'reviewer': 'SnoopyStyle', 'rating': '7'}, {...
# ...                                                  ...
# 69414                                                 []
# 69415                                                 []
# 69416                                                 []
# 69417  [{'reviewer': 'Jack_V05', 'rating': '10'}, {'r...
# 69418  [{'reviewer': 'friedfysh', 'rating': '8'}, {'r...
#
#                               color                                 camera  \
# 0                         ['Color']                                     []
# 1                         ['Color']                                     []
# 2                         ['Color']                                     []
# 3                         ['Color']                                     []
# 4      ['Color', 'Black and White']  ['Red Epic, Panavision Primo Lenses']
# ...                             ...                                    ...
# 69414                            []                                     []
# 69415                            []                                     []
# 69416                            []                                     []
# 69417                     ['Color']                                     []
# 69418                     ['Color']                                     []
#
#                                               laboratory  \
# 0                              ['DeLuxe', 'Technicolor']
# 1      ['DeLuxe', 'EFILM Digital Laboratories, Hollyw...
# 2                        ['DeLuxe, Hollywood (CA), USA']
# 3                                    ['DeLuxe', 'EFilm']
# 4      ['Company 3, Los Angeles (CA), USA', 'DeLuxe, ...
# ...                                                  ...
# 69414                                                 []
# 69415                                                 []
# 69416                                                 []
# 69417                                                 []
# 69418                                                 []
#
#                             film_length           negative_format  \
# 0                           ['2,537 m']               ['Digital']
# 1      ['2,673 m', '2,685 m (5 reels)']               ['Digital']
# 2                 ['2,843 m (6 reels)']               ['Digital']
# 3                ['2,600 m', '4,285 m']               ['Digital']
# 4                 ['3,575 m (7 reels)']  ['35 mm', 'Redcode RAW']
# ...                                 ...                       ...
# 69414                                []                        []
# 69415                                []                        []
# 69416                                []                        []
# 69417                                []                        []
# 69418                                []                        []
#
#                        cinematographic_process  \
# 0          ['Digital', 'Digital Intermediate']
# 1      ['Digital 3-D', 'Digital Intermediate']
# 2      ['Digital 3-D', 'Digital Intermediate']
# 3      ['Digital 3-D', 'Digital Intermediate']
# 4      ['Digital Intermediate', 'Redcode RAW']
# ...                                        ...
# 69414        ['Learn more about contributing']
# 69415        ['Learn more about contributing']
# 69416        ['Learn more about contributing']
# 69417                                       []
# 69418                                       []
#
#                                      printed_film_format  \
# 0                                  ['35 mm', 'D-Cinema']
# 1                                  ['35 mm', 'D-Cinema']
# 2                                  ['35 mm', 'D-Cinema']
# 3                                  ['35 mm', 'D-Cinema']
# 4                         ['35 mm', '70 mm', 'D-Cinema']
# ...                                                  ...
# 69414  ['https://contribute.imdb.com/czone?ref_=ttexr...
# 69415  ['https://contribute.imdb.com/czone?ref_=ttexr...
# 69416  ['https://contribute.imdb.com/czone?ref_=ttexr...
# 69417                                                 []
# 69418                                                 []
#
#                                        review_site_names  \
# 0      ['ReelViews [James Berardinelli]', 'Village Vo...
# 1      ['RogerEbert.com [Odie Henderson]', 'ReelViews...
# 2      ['ReelViews [James Berardinelli]', 'FlickFilos...
# 3      ['ReelViews [James Berardinelli]', 'San Franci...
# 4      ['ReelViews [James Berardinelli]', 'Rolling St...
# ...                                                  ...
# 69414                                                NaN
# 69415                                                NaN
# 69416                                                NaN
# 69417                  ['Learn more about contributing']
# 69418                  ['Learn more about contributing']
#
#                                         review_site_urls
# 0      ['http://www.reelviews.net/reelviews/madagasca...
# 1      ['http://www.rogerebert.com/reviews/despicable...
# 2      ['http://www.reelviews.net/reelviews/monsters-...
# 3      ['http://www.reelviews.net/php_review_template...
# 4      ['http://www.reelviews.net/php_review_template...
# ...                                                  ...
# 69414                                                NaN
# 69415                                                NaN
# 69416                                                NaN
# 69417  ['https://contribute.imdb.com/czone?ref_=ttexr...
# 69418  ['https://contribute.imdb.com/czone?ref_=ttexr...
#
# [69419 rows x 43 columns]

# %% [markdown]
# ### Shape (to see how many titles have been scraped)

# %%
df_scraped.shape
# Out:
# (69419, 43)

# %% [markdown]
# ### Column names

# %%
df_scraped.columns
# Out:
# Index(['imdb_id', ' title', ' runtime', ' sound_mix', ' aspect_ratio',
#        ' budget', ' gross_us_canada', ' opening_weekend_us_canada',
#        ' gross_worldwide', ' writers', ' release_date', ' countries_of_origin',
#        ' official_sites', ' director', ' stars', ' user_reviews',
#        ' critic_reviews', ' metascore', ' languages', ' also_known_as',
#        ' filming_locations', ' production_companies', ' depth',
#        ' download_timeout', ' download_slot', ' download_latency',
#        ' redirect_times', ' redirect_ttl', ' redirect_urls',
#        ' redirect_reasons', ' plot_summaries', ' synopsis', ' reviews_data',
#        ' reviewer_ratings', ' color', ' camera', ' laboratory', ' film_length',
#        ' negative_format', ' cinematographic_process', ' printed_film_format',
#        ' review_site_names', ' review_site_urls'],
#       dtype='object')

# %% [markdown]
# ### Scraped data head

# %%
df_scraped.head()
# Out:
# Warning: Total number of columns (43) exceeds max_columns (20). Falling back to pandas display.
#      imdb_id                               title               runtime  \
# 0  tt1277953  Madagascar 3: Europe's Most Wanted  ['1h 35m', '1h 33m']
# 1  tt1690953                     Despicable Me 2            ['1h 38m']
# 2  tt1453405                 Monsters University            ['1h 44m']
# 3  tt1482459                           The Lorax            ['1h 26m']
# 4  tt1623205           Oz the Great and Powerful            ['2h 10m']
#
#                                            sound_mix  \
# 0  ['Datasat', 'Dolby Digital', 'SDDS', 'Dolby Su...
# 1  ['Dolby Digital', 'Datasat', 'SDDS', 'Dolby At...
# 2  ['Dolby Atmos', 'Datasat', 'SDDS', 'Auro 11.1'...
# 3  ['Dolby Digital', 'Datasat', 'SDDS', 'Auro 11....
# 4  ['SDDS', 'Datasat', 'Dolby Digital', 'Dolby At...
#
#                            aspect_ratio                    budget  \
# 0  ['1.78 : 1', '1.85 : 1', '1.85 : 1']  $145,000,000 (estimated)
# 1  ['1.85 : 1', '1.91 : 1', '2.35 : 1']   $76,000,000 (estimated)
# 2                          ['1.85 : 1']  $200,000,000 (estimated)
# 3                          ['1.85 : 1']   $70,000,000 (estimated)
# 4              ['1.33 : 1', '2.39 : 1']  $215,000,000 (estimated)
#
#    gross_us_canada  opening_weekend_us_canada  gross_worldwide  \
# 0     $216,391,482  $60,316,738, Jun 10, 2012     $746,921,274
# 1     $368,065,385   $83,517,315, Jul 7, 2013     $970,766,005
# 2     $268,492,764  $82,429,469, Jun 23, 2013     $743,559,645
# 3     $214,373,500   $70,217,070, Mar 4, 2012     $349,183,316
# 4     $234,911,825  $79,110,453, Mar 10, 2013     $493,311,825
#
#                                              writers  ...  \
# 0                                                 []  ...
# 1  ['Cinco Paul', 'Ken Daurio', 'Cinco Paul', 'Ke...  ...
# 2                                                 []  ...
# 3  ['Dr. Seuss', 'Cinco Paul', 'Ken Daurio', 'Dr....  ...
# 4                                                 []  ...
#
#                                     reviewer_ratings  \
# 0  [{'reviewer': 'DICK STEEL', 'rating': '8'}, {'...
# 1  [{'reviewer': 'claudio_carvalho', 'rating': '7...
# 2  [{'reviewer': 'claudio_carvalho', 'rating': '8...
# 3  [{'reviewer': 'pawanpunjabithewriter', 'rating...
# 4  [{'reviewer': 'SnoopyStyle', 'rating': '7'}, {...
#
#                           color                                 camera  \
# 0                     ['Color']                                     []
# 1                     ['Color']                                     []
# 2                     ['Color']                                     []
# 3                     ['Color']                                     []
# 4  ['Color', 'Black and White']  ['Red Epic, Panavision Primo Lenses']
#
#                                           laboratory  \
# 0                          ['DeLuxe', 'Technicolor']
# 1  ['DeLuxe', 'EFILM Digital Laboratories, Hollyw...
# 2                    ['DeLuxe, Hollywood (CA), USA']
# 3                                ['DeLuxe', 'EFilm']
# 4  ['Company 3, Los Angeles (CA), USA', 'DeLuxe, ...
#
#                         film_length           negative_format  \
# 0                       ['2,537 m']               ['Digital']
# 1  ['2,673 m', '2,685 m (5 reels)']               ['Digital']
# 2             ['2,843 m (6 reels)']               ['Digital']
# 3            ['2,600 m', '4,285 m']               ['Digital']
# 4             ['3,575 m (7 reels)']  ['35 mm', 'Redcode RAW']
#
#                    cinematographic_process             printed_film_format  \
# 0      ['Digital', 'Digital Intermediate']           ['35 mm', 'D-Cinema']
# 1  ['Digital 3-D', 'Digital Intermediate']           ['35 mm', 'D-Cinema']
# 2  ['Digital 3-D', 'Digital Intermediate']           ['35 mm', 'D-Cinema']
# 3  ['Digital 3-D', 'Digital Intermediate']           ['35 mm', 'D-Cinema']
# 4  ['Digital Intermediate', 'Redcode RAW']  ['35 mm', '70 mm', 'D-Cinema']
#
#                                    review_site_names  \
# 0  ['ReelViews [James Berardinelli]', 'Village Vo...
# 1  ['RogerEbert.com [Odie Henderson]', 'ReelViews...
# 2  ['ReelViews [James Berardinelli]', 'FlickFilos...
# 3  ['ReelViews [James Berardinelli]', 'San Franci...
# 4  ['ReelViews [James Berardinelli]', 'Rolling St...
#
#                                     review_site_urls
# 0  ['http://www.reelviews.net/reelviews/madagasca...
# 1  ['http://www.rogerebert.com/reviews/despicable...
# 2  ['http://www.reelviews.net/reelviews/monsters-...
# 3  ['http://www.reelviews.net/php_review_template...
# 4  ['http://www.reelviews.net/php_review_template...
#
# [5 rows x 43 columns]

# %%
df_scraped.describe()
# Out:
#           metascore         depth   download_timeout   download_latency  \
# count  12677.000000  69419.000000            69419.0       69419.000000
# mean      53.366254      5.856725              180.0           0.492765
# std       17.092228      9.226569                0.0           0.286522
# min        1.000000      4.000000              180.0           0.192495
# 25%       41.000000      4.000000              180.0           0.374598
# 50%       54.000000      4.000000              180.0           0.420266
# 75%       66.000000      4.000000              180.0           0.515759
# max      100.000000    461.000000              180.0           8.423579
#
#         redirect_times   redirect_ttl
# count          69419.0        69419.0
# mean               2.0           18.0
# std                0.0            0.0
# min                2.0           18.0
# 25%                2.0           18.0
# 50%                2.0           18.0
# 75%                2.0           18.0
# max                2.0           18.0

# %% [markdown]
# ### Info and Dtypes

# %%
df_scraped.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69419 entries, 0 to 69418
# Data columns (total 43 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   imdb_id                     69419 non-null  object
#  1    title                      69419 non-null  object
#  2    runtime                    69419 non-null  object
#  3    sound_mix                  69419 non-null  object
#  4    aspect_ratio               69419 non-null  object
#  5    budget                     27933 non-null  object
#  6    gross_us_canada            12709 non-null  object
#  7    opening_weekend_us_canada  69419 non-null  object
#  8    gross_worldwide            19028 non-null  object
#  9    writers                    69419 non-null  object
#  10   release_date               65652 non-null  object
#  11   countries_of_origin        69419 non-null  object
#  12   official_sites             69419 non-null  object
#  13   director                   68036 non-null  object
#  14   stars                      69419 non-null  object
#  15   user_reviews               45662 non-null  object
#  16   critic_reviews             39708 non-null  object
#  17   metascore                  12677 non-null  float64
#  18   languages                  69419 non-null  object
#  19   also_known_as              40673 non-null  object
#  20   filming_locations          48982 non-null  object
#  21   production_companies       69419 non-null  object
#  22   depth                      69419 non-null  int64
#  23   download_timeout           69419 non-null  float64
#  24   download_slot              69419 non-null  object
#  25   download_latency           69419 non-null  float64
#  26   redirect_times             69419 non-null  int64
#  27   redirect_ttl               69419 non-null  int64
#  28   redirect_urls              69419 non-null  object
#  29   redirect_reasons           69419 non-null  object
#  30   plot_summaries             69419 non-null  object
#  31   synopsis                   66458 non-null  object
#  32   reviews_data               69419 non-null  object
#  33   reviewer_ratings           69419 non-null  object
#  34   color                      69419 non-null  object
#  35   camera                     69419 non-null  object
#  36   laboratory                 69419 non-null  object
#  37   film_length                69419 non-null  object
#  38   negative_format            69419 non-null  object
#  39   cinematographic_process    69419 non-null  object
#  40   printed_film_format        69419 non-null  object
#  41   review_site_names          52832 non-null  object
#  42   review_site_urls           52832 non-null  object
# dtypes: float64(3), int64(3), object(37)
# memory usage: 22.8+ MB

# %% [markdown]
# ### Check for duplicated movies

# %%
 df_scraped[df_scraped.duplicated('imdb_id', keep=False)]
# Out:
# Warning: Total number of columns (43) exceeds max_columns (20). Falling back to pandas display.
# Empty DataFrame
# Columns: [imdb_id,  title,  runtime,  sound_mix,  aspect_ratio,  budget,  gross_us_canada,  opening_weekend_us_canada,  gross_worldwide,  writers,  release_date,  countries_of_origin,  official_sites,  director,  stars,  user_reviews,  critic_reviews,  metascore,  languages,  also_known_as,  filming_locations,  production_companies,  depth,  download_timeout,  download_slot,  download_latency,  redirect_times,  redirect_ttl,  redirect_urls,  redirect_reasons,  plot_summaries,  synopsis,  reviews_data,  reviewer_ratings,  color,  camera,  laboratory,  film_length,  negative_format,  cinematographic_process,  printed_film_format,  review_site_names,  review_site_urls]
# Index: []
#
# [0 rows x 43 columns]

# %% [markdown]
# ### Make a copy of the df_scraped and save it to df, to clean it

# %%
df = df_scraped.copy()

# %% [markdown]
# ### Number of null values:

# %%
df.isnull().sum()
# Out:
# imdb_id                           0
#  title                            0
#  runtime                          0
#  sound_mix                        0
#  aspect_ratio                     0
#  budget                       41486
#  gross_us_canada              56710
#  opening_weekend_us_canada        0
#  gross_worldwide              50391
#  writers                          0
#  release_date                  3767
#  countries_of_origin              0
#  official_sites                   0
#  director                      1383
#  stars                            0
#  user_reviews                 23757
#  critic_reviews               29711
#  metascore                    56742
#  languages                        0
#  also_known_as                28746
#  filming_locations            20437
#  production_companies             0
#  depth                            0
#  download_timeout                 0
#  download_slot                    0
#  download_latency                 0
#  redirect_times                   0
#  redirect_ttl                     0
#  redirect_urls                    0
#  redirect_reasons                 0
#  plot_summaries                   0
#  synopsis                      2961
#  reviews_data                     0
#  reviewer_ratings                 0
#  color                            0
#  camera                           0
#  laboratory                       0
#  film_length                      0
#  negative_format                  0
#  cinematographic_process          0
#  printed_film_format              0
#  review_site_names            16587
#  review_site_urls             16587
# dtype: int64

# %% [markdown]
# # **Cleaning Columns Part 1: Basic Information and Transformation**
#
# In this section, we'll tackle various tasks that revolve around cleaning basic information and transforming the data.
#
# ##### **Understanding the Columns**
# We'll start by examining the column names, types, and identifying any immediate issues that need to be addressed.
#
# ##### **Renaming Columns**
# - Rename columns to make them more consistent and free from unwanted characters or spaces.
#
# ##### **Standardizing Formats**
# - Convert the runtime column into a standard format (e.g., from string to numerical values).
#
# ##### **Cleaning Specific Columns**
# - Address and clean the sound_mix, aspect_ratio, budget, and gross_us_canada columns.
#
# ##### **Creating New Columns**
# - Create new columns such as budget_estimated for further analysis.
#
# ##### **Handling Country Information**
# - Transform and merge information related to the countries of origin.
#
# ##### **Processing Directors, Writers, and Stars**
# - Extract, organize, and clean information related to directors, writers, and stars.

# %%
df.iloc[:,:7].head()
# Out:
#      imdb_id                               title               runtime  \
# 0  tt1277953  Madagascar 3: Europe's Most Wanted  ['1h 35m', '1h 33m']
# 1  tt1690953                     Despicable Me 2            ['1h 38m']
# 2  tt1453405                 Monsters University            ['1h 44m']
# 3  tt1482459                           The Lorax            ['1h 26m']
# 4  tt1623205           Oz the Great and Powerful            ['2h 10m']
#
#                                            sound_mix  \
# 0  ['Datasat', 'Dolby Digital', 'SDDS', 'Dolby Su...
# 1  ['Dolby Digital', 'Datasat', 'SDDS', 'Dolby At...
# 2  ['Dolby Atmos', 'Datasat', 'SDDS', 'Auro 11.1'...
# 3  ['Dolby Digital', 'Datasat', 'SDDS', 'Auro 11....
# 4  ['SDDS', 'Datasat', 'Dolby Digital', 'Dolby At...
#
#                            aspect_ratio                    budget  \
# 0  ['1.78 : 1', '1.85 : 1', '1.85 : 1']  $145,000,000 (estimated)
# 1  ['1.85 : 1', '1.91 : 1', '2.35 : 1']   $76,000,000 (estimated)
# 2                          ['1.85 : 1']  $200,000,000 (estimated)
# 3                          ['1.85 : 1']   $70,000,000 (estimated)
# 4              ['1.33 : 1', '2.39 : 1']  $215,000,000 (estimated)
#
#    gross_us_canada
# 0     $216,391,482
# 1     $368,065,385
# 2     $268,492,764
# 3     $214,373,500
# 4     $234,911,825

# %% [markdown]
# From this, we can see that the issues lie with the columns `runtime`, `sound_mix`, `aspect_ratio`. For `budget` and `gross_us_canada`, we want to change the format. I will make a new column, `budget_estimated` that will say 1 or 0.
#
#
# Also all the column names have spaces in them, gotta deal with that first

# %% [markdown]
# #### Renaming columns

# %%
df.columns = df.columns.str.strip()

# %% [markdown]
# ### -`runtime`- column

# %% [markdown]
# Defining function to convert runtime

# %%
import ast

def convert_runtime(runtime_str):
    runtime = ast.literal_eval(runtime_str)
    if len(runtime) == 0:  # if runtime list is empty, return None or a specific value
        return None
    total = 0
    for time in runtime:
        time = time.strip()
        if 'h' in time and 'm' in time:
            h, m = time.split('h')
            total += int(h.strip()) * 60 + int(m.replace('m', '').strip())
        elif 'h' in time:
            h = time.replace('h', '')
            total += int(h.strip()) * 60
        elif 'm' in time:
            m = time.replace('m', '')
            total += int(m.strip())
    return total / len(runtime)

# %% [markdown]
# Applying `convert_runtime` function to `runtime` column

# %%
df['runtime'] = df['runtime'].apply(convert_runtime)

# %% [markdown]
# Filling NaN values with 0 to keep column an int

# %%
df['runtime'] = df['runtime'].fillna(0).astype(int)

# Code to drop rows without the runtime information (cannot use the above fillna function), might be used for other columns to drop titles that are irrelevant
# df = df.dropna(subset=['runtime'])
# df['runtime'] = df['runtime'].astype(int)

# %%
print(f"Original runtime column vs cleaned runtime column: \n\n Old:\n\n {df_scraped[' runtime'].head(10)}\n\n New: \n\n{df['runtime'].head(10)}")
# Out:
# Original runtime column vs cleaned runtime column:
#
#  Old:
#
#  0    ['1h 35m', '1h 33m']
# 1              ['1h 38m']
# 2              ['1h 44m']
# 3              ['1h 26m']
# 4              ['2h 10m']
# 5    ['2h 10m', '2h 11m']
# 6     ['1h 55m', '2h 2m']
# 7              ['1h 38m']
# 8              ['1h 33m']
# 9              ['2h 26m']
# Name:  runtime, dtype: object
#
#  New:
#
# 0     94
# 1     98
# 2    104
# 3     86
# 4    130
# 5    130
# 6    118
# 7     98
# 8     93
# 9    146
# Name: runtime, dtype: int64

# %% [markdown]
# Alright, moving on, what's next?

# %%
df.iloc[:,3:4].head()
# Out:
#                                            sound_mix
# 0  ['Datasat', 'Dolby Digital', 'SDDS', 'Dolby Su...
# 1  ['Dolby Digital', 'Datasat', 'SDDS', 'Dolby At...
# 2  ['Dolby Atmos', 'Datasat', 'SDDS', 'Auro 11.1'...
# 3  ['Dolby Digital', 'Datasat', 'SDDS', 'Auro 11....
# 4  ['SDDS', 'Datasat', 'Dolby Digital', 'Dolby At...

# %% [markdown]
# ### -`sound_mix`- column

# %% [markdown]
# getting rid of the unnecessary []

# %%
df['sound_mix'] = df['sound_mix'].apply(ast.literal_eval)

# %%
df['sound_mix']
# Out:
# 0        [Datasat, Dolby Digital, SDDS, Dolby Surround ...
# 1        [Dolby Digital, Datasat, SDDS, Dolby Atmos, Do...
# 2        [Dolby Atmos, Datasat, SDDS, Auro 11.1, Dolby ...
# 3        [Dolby Digital, Datasat, SDDS, Auro 11.1, Dolb...
# 4        [SDDS, Datasat, Dolby Digital, Dolby Atmos, Do...
#                                ...
# 69414                                                   []
# 69415                                                   []
# 69416                                                   []
# 69417                                                   []
# 69418                                                   []
# Name: sound_mix, Length: 69419, dtype: object

# %%
df.iloc[:,3:4].head()
# Out:
#                                            sound_mix
# 0  [Datasat, Dolby Digital, SDDS, Dolby Surround ...
# 1  [Dolby Digital, Datasat, SDDS, Dolby Atmos, Do...
# 2  [Dolby Atmos, Datasat, SDDS, Auro 11.1, Dolby ...
# 3  [Dolby Digital, Datasat, SDDS, Auro 11.1, Dolb...
# 4  [SDDS, Datasat, Dolby Digital, Dolby Atmos, Do...

# %% [markdown]
# Need to count number of different types of sound mixes there are

# %%
# Make a new dataframe for the sound_mix column just for ease of processing
sound_mix_list = df['sound_mix']

# Flatten the list and get the count of each sound mix
sound_mix_counts = pd.Series([item for sublist in sound_mix_list for item in sublist]).value_counts()

sound_mix_counts
# Out:
# Dolby Digital                        13104
# Stereo                                5148
# DTS                                   3326
# Dolby                                 3039
# SDDS                                  2716
# Mono                                  2282
# Dolby SR                              1435
# Dolby Atmos                           1195
# Dolby Stereo                           924
# Dolby Surround 7.1                     711
# Ultra Stereo                           710
# Datasat                                637
# D-Cinema 48kHz 5.1                     409
# Auro 11.1                              211
# IMAX 6-Track                           180
# Dolby Digital EX                       174
# 70 mm 6-Track                          144
# Sonics-DDP                             129
# 12-Track Digital Sound                 128
# DTS-Stereo                             113
# 6-Track Stereo                          85
# DTS-ES                                  58
# D-Cinema 96kHz 5.1                      53
# 4-Track Stereo                          36
# DX Stereo                               25
# 3 Channel Stereo                        18
# Silent                                  15
# Matrix Surround                         15
# D-Cinema 48kHz 7.1                      12
# DTS 70 mm                               12
# CDS                                     10
# D-Cinema 48kHz Dolby Surround 7.1       10
# D-Cinema 96kHz Dolby Surround 7.1       10
# Cinesound                                8
# D-Cinema 96kHz 7.1                       8
# Chace Surround                           7
# DTS:X                                    6
# WANOS                                    5
# Sound Trax Surround Stereo               5
# Full Range Recording System              5
# Digitrac Digital Audio System            4
# Soundelux                                4
# Broadway Surround                        4
# Sensurround                              3
# Spectra-Stereo                           3
# LC-Concept Digital Sound                 3
# HoloSound                                2
# Vistasonic                               2
# Servotron Stereo                         2
# DTS-8                                    2
# Sound 360°                               2
# Cinerama 7-Track                         2
# Auro 9.1                                 1
# TMH Labs 10.2 Channel Sound              1
# Sonics                                   1
# Iwerks Digital Audio                     1
# Cinephone                                1
# AGA Sound System                         1
# Aurofone                                 1
# dtype: int64

# %% [markdown]
# Great `sound_mix` is cleaned. Note to self: I should use one-hot encoding later (not dummify as I want to also gain EDA insights from the columns)

# %% [markdown]
# ### -`aspect_ratio`- column

# %%
df.iloc[:,4:5].head()
# Out:
#                            aspect_ratio
# 0  ['1.78 : 1', '1.85 : 1', '1.85 : 1']
# 1  ['1.85 : 1', '1.91 : 1', '2.35 : 1']
# 2                          ['1.85 : 1']
# 3                          ['1.85 : 1']
# 4              ['1.33 : 1', '2.39 : 1']

# %%
df['aspect_ratio'] = df['aspect_ratio'].apply(ast.literal_eval)

# %%
df.iloc[:,4:5].head()
# Out:
#                      aspect_ratio
# 0  [1.78 : 1, 1.85 : 1, 1.85 : 1]
# 1  [1.85 : 1, 1.91 : 1, 2.35 : 1]
# 2                      [1.85 : 1]
# 3                      [1.85 : 1]
# 4            [1.33 : 1, 2.39 : 1]

# %%
# Make a new dataframe for the `aspect_ratio` column
aspect_ratio_list = df['aspect_ratio']

# Flatten the list and get the count of each sound mix
aspect_ratio_counts = pd.Series([item for sublist in aspect_ratio_list for item in sublist]).value_counts()

aspect_ratio_counts
# Out:
# 1.85 : 1           12736
# 2.35 : 1           10313
# 1.78 : 1            4209
# 16:9 HD             2678
# 2.39 : 1            2547
#                    ...
# 1.78 : 1 (HDTV)        1
# 2.16 : 1               1
# 1.79:1                 1
# 2.35:1 and 16:9        1
# 1080x1920              1
# Length: 260, dtype: int64

# %%
aspect_ratio_counts.to_csv("/content/drive/MyDrive/IMDB Project/Cleaning1/cleaned_data/aspect_ratio_counts.csv", encoding = "utf-8")

# %%
# %cd /content/drive/MyDrive/IMDB Project/Cleaning1/cleaned_data
# Out:
# /content/drive/MyDrive/IMDB Project/Cleaning1/cleaned_data

# %% [markdown]
# ### -`budget`- column

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69419 entries, 0 to 69418
# Data columns (total 43 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   imdb_id                    69419 non-null  object
#  1   title                      69419 non-null  object
#  2   runtime                    69419 non-null  int64
#  3   sound_mix                  69419 non-null  object
#  4   aspect_ratio               69419 non-null  object
#  5   budget                     27933 non-null  object
#  6   gross_us_canada            12709 non-null  object
#  7   opening_weekend_us_canada  69419 non-null  object
#  8   gross_worldwide            19028 non-null  object
#  9   writers                    69419 non-null  object
#  10  release_date               65652 non-null  object
#  11  countries_of_origin        69419 non-null  object
#  12  official_sites             69419 non-null  object
#  13  director                   68036 non-null  object
#  14  stars                      69419 non-null  object
#  15  user_reviews               45662 non-null  object
#  16  critic_reviews             39708 non-null  object
#  17  metascore                  12677 non-null  float64
#  18  languages                  69419 non-null  object
#  19  also_known_as              40673 non-null  object
#  20  filming_locations          48982 non-null  object
#  21  production_companies       69419 non-null  object
#  22  depth                      69419 non-null  int64
#  23  download_timeout           69419 non-null  float64
#  24  download_slot              69419 non-null  object
#  25  download_latency           69419 non-null  float64
#  26  redirect_times             69419 non-null  int64
#  27  redirect_ttl               69419 non-null  int64
#  28  redirect_urls              69419 non-null  object
#  29  redirect_reasons           69419 non-null  object
#  30  plot_summaries             69419 non-null  object
#  31  synopsis                   66458 non-null  object
#  32  reviews_data               69419 non-null  object
#  33  reviewer_ratings           69419 non-null  object
#  34  color                      69419 non-null  object
#  35  camera                     69419 non-null  object
#  36  laboratory                 69419 non-null  object
#  37  film_length                69419 non-null  object
#  38  negative_format            69419 non-null  object
#  39  cinematographic_process    69419 non-null  object
#  40  printed_film_format        69419 non-null  object
#  41  review_site_names          52832 non-null  object
#  42  review_site_urls           52832 non-null  object
# dtypes: float64(3), int64(4), object(36)
# memory usage: 22.8+ MB

# %%
print(df.iloc[:,5:9].head(20))
# Out:
#                       budget gross_us_canada   opening_weekend_us_canada  \
# 0   $145,000,000 (estimated)    $216,391,482   $60,316,738, Jun 10, 2012
# 1    $76,000,000 (estimated)    $368,065,385    $83,517,315, Jul 7, 2013
# 2   $200,000,000 (estimated)    $268,492,764   $82,429,469, Jun 23, 2013
# 3    $70,000,000 (estimated)    $214,373,500    $70,217,070, Mar 4, 2012
# 4   $215,000,000 (estimated)    $234,911,825   $79,110,453, Mar 10, 2013
# 5   $160,000,000 (estimated)    $238,679,850   $97,375,245, May 26, 2013
# 6   $120,000,000 (estimated)    $292,324,737  $141,067,634, Nov 18, 2012
# 7   $135,000,000 (estimated)    $187,168,425   $43,639,736, Mar 24, 2013
# 8   $185,000,000 (estimated)    $237,283,207   $66,323,594, Jun 24, 2012
# 9   $130,000,000 (estimated)    $424,668,047  $158,074,286, Nov 24, 2013
# 10  $165,000,000 (estimated)    $189,422,889    $49,038,712, Nov 4, 2012
# 11   $50,000,000 (estimated)    $218,815,487    $54,415,205, Jul 1, 2012
# 12   $95,000,000 (estimated)    $161,321,843   $46,629,259, Jul 15, 2012
# 13  $225,000,000 (estimated)    $258,387,334   $73,645,197, Dec 15, 2013
# 14  $225,000,000 (estimated)    $179,020,854   $54,592,779, May 27, 2012
# 15  $170,000,000 (estimated)    $206,362,140   $85,737,841, Nov 10, 2013
# 16  $150,000,000 (estimated)    $400,953,009      $243,390, Nov 24, 2013
# 17   $85,000,000 (estimated)    $148,313,048   $42,522,194, Sep 30, 2012
# 18   $43,000,000 (estimated)    $159,582,188   $39,115,043, Jun 30, 2013
# 19   $37,000,000 (estimated)    $150,394,119   $26,419,396, Aug 11, 2013
#
#    gross_worldwide
# 0     $746,921,274
# 1     $970,766,005
# 2     $743,559,645
# 3     $349,183,316
# 4     $493,311,825
# 5     $788,680,968
# 6     $848,593,948
# 7     $587,235,983
# 8     $538,983,207
# 9     $865,011,746
# 10    $471,222,889
# 11    $549,368,315
# 12    $877,244,782
# 13    $959,027,992
# 14    $654,213,485
# 15    $644,783,140
# 16  $1,284,540,518
# 17    $358,375,603
# 18    $229,930,771
# 19    $269,994,119

# %%
# Extract the budget and budget_type
new_cols = df['budget'].str.extract(r'(\$[0-9,]+)\s*\((.*)\)', expand=True)

# If the above line doesn't work, try this:
# new_cols = df['budget'].str.extract(r'(\$[0-9,]+)\((.*)\)', expand=True)

# Fill NaN values in 'budget_type' column with 'NIL'
new_cols[1].fillna('NIL', inplace=True)

# Get the index of the 'budget' column
idx = df.columns.get_loc('budget')

# Insert the new columns before the 'budget' column
df.insert(idx, 'budget($)', new_cols[0])
df.insert(idx + 1, 'budget_type', new_cols[1])

# %%
# Remove the dollar signs
df['budget($)'] = df['budget($)'].str.replace('$', '')

# Convert the column to float
df['budget($)'] = df['budget($)'].str.replace(',', '').astype(float)
# Out:
# <ipython-input-201-d682cde18ef1>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['budget($)'] = df['budget($)'].str.replace('$', '')

# %%
df= df.sort_values(by='budget($)', ascending=False)
df = df.reset_index(drop=True)

# %%
df.iloc[:,5:8].head()
# Out:
#       budget($) budget_type                        budget
# 0  2.000000e+09   estimated  HK$2,000,000,000 (estimated)
# 1  8.000000e+08   estimated    NT$800,000,000 (estimated)
# 2  3.560000e+08   estimated      $356,000,000 (estimated)
# 3  3.500000e+08   estimated      $350,000,000 (estimated)
# 4  3.400000e+08   estimated      $340,000,000 (estimated)

# %% [markdown]
# Great! Next.

# %% [markdown]
# ### -`gross_us_canada`- column

# %%
df.iloc[:,7:9].head()
# Out:
#                          budget gross_us_canada
# 0  HK$2,000,000,000 (estimated)             NaN
# 1    NT$800,000,000 (estimated)             NaN
# 2      $356,000,000 (estimated)       858373000
# 3      $350,000,000 (estimated)       684075767
# 4      $340,000,000 (estimated)       145960660

# %%
df['gross_us_canada'] = df['gross_us_canada'].str.replace('[$,]', '', regex=True)

# %%
df['gross_us_canada']
# Out:
# 0        216391482
# 1        368065385
# 2        268492764
# 3        214373500
# 4        234911825
#            ...
# 69414          NaN
# 69415          NaN
# 69416          NaN
# 69417          NaN
# 69418          NaN
# Name: gross_us_canada, Length: 69419, dtype: object

# %% [markdown]
# ### `opening_weekend_us_canada` column

# %%
df['opening_weekend_us_canada']
# Out:
# 0        $60,316,738, Jun 10, 2012
# 1         $83,517,315, Jul 7, 2013
# 2        $82,429,469, Jun 23, 2013
# 3         $70,217,070, Mar 4, 2012
# 4        $79,110,453, Mar 10, 2013
#                    ...
# 69414                   None, None
# 69415                   None, None
# 69416                   None, None
# 69417                   None, None
# 69418                   None, None
# Name: opening_weekend_us_canada, Length: 69419, dtype: object

# %%
# Split the column into two from the second rightmost comma, to a new df titled `df_temp`
df_temp = df['opening_weekend_us_canada'].str.rsplit(',', 2, expand=True)
# Out:
# <ipython-input-210-2ffb4a4eee90>:2: FutureWarning: In a future version of pandas all arguments of StringMethods.rsplit except for the argument 'pat' will be keyword-only.
#   df_temp = df['opening_weekend_us_canada'].str.rsplit(',', 2, expand=True)

# %%
import numpy as np

#Replace the string "None" with np.nan
df_temp[0] = df_temp[0].replace('None', np.nan)

# %%
# Clean and convert the opening_weekend_revenue column
df_temp[0] = df_temp[0].str.replace('[$,]', '', regex=True).astype(float)

# %%
# Combine the date and year back into a single column and convert to datetime
df_temp[1] = pd.to_datetime(df_temp[1].str.strip() + ', ' + df_temp[2].str.strip(), format='%b %d, %Y')

# %%
df_temp.head()
# Out:
#             0          1      2
# 0  60316738.0 2012-06-10   2012
# 1  83517315.0 2013-07-07   2013
# 2  82429469.0 2013-06-23   2013
# 3  70217070.0 2012-03-04   2012
# 4  79110453.0 2013-03-10   2013

# %%
# Insert the new columns into the original DataFrame
df.insert(10, 'opening_weekend_revenue(USD)', df_temp[0])
df.insert(11, 'opening_weekend_date', df_temp[1])

# %%
# Convert the datetime object to just date
df['opening_weekend_date'] = df['opening_weekend_date'].dt.date

# %%
df.iloc[:,7:13].head()
# Out:
#                          budget gross_us_canada   opening_weekend_us_canada  \
# 0  HK$2,000,000,000 (estimated)             NaN                  None, None
# 1    NT$800,000,000 (estimated)             NaN                  None, None
# 2      $356,000,000 (estimated)       858373000  $357,115,007, Apr 28, 2019
# 3      $350,000,000 (estimated)       684075767  $134,100,226, Dec 18, 2022
# 4      $340,000,000 (estimated)       145960660   $67,017,410, May 21, 2023
#
#    opening_weekend_revenue(USD) opening_weekend_date gross_worldwide_usd
# 0                           NaN                  NaT                 NaN
# 1                           NaN                  NaT            $288,422
# 2                   357115007.0           2019-04-28      $2,799,439,100
# 3                   134100226.0           2022-12-18      $2,320,250,281
# 4                    67017410.0           2023-05-21        $704,709,660

# %% [markdown]
# ### -`gross_worldwide`- column

# %%
df.iloc[:,12:14].head()
# Out:
#   gross_worldwide                                            writers
# 0    $746,921,274                                                 []
# 1    $970,766,005  ['Cinco Paul', 'Ken Daurio', 'Cinco Paul', 'Ke...
# 2    $743,559,645                                                 []
# 3    $349,183,316  ['Dr. Seuss', 'Cinco Paul', 'Ken Daurio', 'Dr....
# 4    $493,311,825                                                 []

# %%
df = df.rename(columns={'gross_worldwide':'gross_worldwide_usd'})

# %% [markdown]
# ### -`writers`- column

# %%
df.iloc[:,13:14].head(100)
# Out:
#                                               writers
# 0                                                  []
# 1   ['Cinco Paul', 'Ken Daurio', 'Cinco Paul', 'Ke...
# 2                                                  []
# 3   ['Dr. Seuss', 'Cinco Paul', 'Ken Daurio', 'Dr....
# 4                                                  []
# ..                                                ...
# 95                                                 []
# 96                                                 []
# 97  ['Terence Winter', 'Jordan Belfort', 'Terence ...
# 98                                                 []
# 99  ['Lisa Addario', 'Joe Syracuse', 'Lisa Addario...
#
# [100 rows x 1 columns]

# %%
df['writers'] = df['writers'].str.replace("[", "").str.replace("]", "").str.replace("'", "")
# Out:
# <ipython-input-221-de11f4a4fe5d>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['writers'] = df['writers'].str.replace("[", "").str.replace("]", "").str.replace("'", "")

# %%
# Replace all blank spaces with NaN
df['writers'] = df['writers'].apply(lambda x: np.nan if len(x)==0 else x)

# %%
# Remove duplicate entries by converting list to set, then back to string
df['writers'] = df['writers'].apply(lambda x: ', '.join(set(x.split(', '))) if isinstance(x, str) else x)

# %%
df['writers'].value_counts()
# Out:
# Simon Boyes, Adam Mason                  12
# Chris Stokes, Marques Houston            11
# Ethan Coen, Joel Coen                    10
# John Brancato, Michael Ferris             9
# Jason Friedberg, Aaron Seltzer            8
#                                          ..
# Milos Kreckovic, Aleksandar D. Kostic     1
# Robert Hamilton, R. Dani                  1
# Roger Hawkins, Phil Cunningham            1
# Dennis Hatch Christen, Han Woo Yung       1
# Tyler Cheman, Kristen Skeet               1
# Name: writers, Length: 20246, dtype: int64

# %% [markdown]
# ##### Writer's MDM Section
# I realised, that if I want to consider cleaning this data for the purposes of Mastering Data Management, I'd probably want to showcase each individual writer and which projects they have worked on, so I'll save it to a new file:

# %%
# Split the 'writers' column into multiple rows
df_exploded = df.assign(writers=df['writers'].str.split(', ')).explode('writers')

# %%
# Create a new DataFrame that counts the number of movies each writer has made
writer_counts = df_exploded['writers'].value_counts().reset_index()
writer_counts.columns = ['writer', 'movie_count']

# %%
# Create a DataFrame that lists the titles each writer has worked on
writer_titles = df_exploded.groupby('writers')['title'].apply(list).reset_index()
writer_titles.columns = ['writer', 'movie_titles']

# %%
# Merge the two DataFrames
writer_info = pd.merge(writer_counts, writer_titles, on='writer')

# %%
writer_info
# Out:
# Warning: total number of rows (36243) exceeds max_rows (20000). Falling back to pandas display.
#                     writer  movie_count  \
# 0      William Shakespeare           94
# 1             Stephen King           43
# 2           H.P. Lovecraft           26
# 3          Edgar Allan Poe           21
# 4                Joel Coen           20
# ...                    ...          ...
# 36238          Ahmed Farah            1
# 36239          Clark Young            1
# 36240        Derek Goldman            1
# 36241        Brian Ceponis            1
# 36242        Kristen Skeet            1
#
#                                             movie_titles
# 0      [Much Ado About Nothing, Romeo & Juliet, Romeo...
# 1      [Carrie, Misery, Pet Sematary, Secret Window, ...
# 2      [Banshee Chapter, The Last Case of August T. H...
# 3      [Extraordinary Tales, Stonehearst Asylum, The ...
# 4      [Inside Llewyn Davis, Gambit, Bridge of Spies,...
# ...                                                  ...
# 36238                                          [Ayaanle]
# 36239                                    [Remember This]
# 36240                                    [Remember This]
# 36241                                      [Wolf Hollow]
# 36242                              [Little Green People]
#
# [36243 rows x 3 columns]

# %%
writer_info.to_csv("/content/drive/MyDrive/IMDB Project/Cleaning1/cleaned_data/writer_info.csv", encoding = "utf-8")

# %% [markdown]
# ###### MDM Function

# %%
def get_writer_movies(writer):
    # Filter the exploded DataFrame for rows where the writer is the input writer
    writer_df = df_exploded[df_exploded['writers'] == writer]

    # Get the original rows from df
    original_rows = df[df.index.isin(writer_df.index)]

    return original_rows

# %%
writer_stats = get_writer_movies('Nicholas Sparks')
writer_stats

#This allows me to see all the movies and the details of those movies made by Stephen King
# Out:
# Warning: Total number of columns (47) exceeds max_columns (20). Falling back to pandas display.
#         imdb_id                title  runtime                       sound_mix  \
# 111   tt1702439           Safe Haven      115        [Datasat, Dolby Digital]
# 132   tt1327194        The Lucky One      101  [Dolby Digital, Datasat, SDDS]
# 246   tt1972779       The Best of Me      118                 [Dolby Digital]
# 3669  tt2726560     The Longest Ride      123  [Dolby Digital, Datasat, SDDS]
# 3730  tt3797868           The Choice      111                              []
# 6552  tt0989757            Dear John      108      [Dolby Digital, DTS, SDDS]
# 6616  tt0332280         The Notebook      123      [DTS, Dolby Digital, SDDS]
# 6982  tt0139462  Message in a Bottle      126      [DTS, Dolby Digital, SDDS]
# 7276  tt0956038   Nights in Rodanthe       97      [Dolby Digital, DTS, SDDS]
# 7370  tt0281358   A Walk to Remember      101      [DTS, Dolby Digital, SDDS]
#
#               aspect_ratio   budget($) budget_type                   budget  \
# 111             [2.35 : 1]  28000000.0   estimated  $28,000,000 (estimated)
# 132             [2.35 : 1]  25000000.0   estimated  $25,000,000 (estimated)
# 246             [2.35 : 1]  26000000.0   estimated  $26,000,000 (estimated)
# 3669  [2.35 : 1, 2.39 : 1]  34000000.0   estimated  $34,000,000 (estimated)
# 3730                    []         NaN         NIL                      NaN
# 6552            [2.35 : 1]  25000000.0   estimated  $25,000,000 (estimated)
# 6616            [2.35 : 1]  29000000.0   estimated  $29,000,000 (estimated)
# 6982            [2.39 : 1]  80000000.0   estimated  $80,000,000 (estimated)
# 7276            [2.35 : 1]  30000000.0   estimated  $30,000,000 (estimated)
# 7370            [2.39 : 1]  11800000.0   estimated  $11,800,000 (estimated)
#
#      gross_us_canada  opening_weekend_us_canada  ...  \
# 111         71349120  $21,401,594, Feb 17, 2013  ...
# 132         60457138  $22,518,358, Apr 22, 2012  ...
# 246         26766213  $10,003,827, Oct 19, 2014  ...
# 3669        37446117  $13,019,686, Apr 12, 2015  ...
# 3730        18730891    $6,050,443, Feb 7, 2016  ...
# 6552        80014842   $30,468,614, Feb 7, 2010  ...
# 6616        81417274  $13,464,745, Jun 27, 2004  ...
# 6982        52880016  $16,751,560, Feb 14, 1999  ...
# 7276        41850659  $13,418,454, Sep 28, 2008  ...
# 7370        41281092  $12,177,488, Jan 27, 2002  ...
#
#                                        reviewer_ratings  \
# 111   [{'reviewer': 'JohnRayPeterson', 'rating': '7'...
# 132   [{'reviewer': 'claudio_carvalho', 'rating': '7...
# 246   [{'reviewer': 'A_Different_Drummer', 'rating':...
# 3669  [{'reviewer': 'bkoganbing', 'rating': '8'}, {'...
# 3730  [{'reviewer': 'cosmo_tiger', 'rating': '8'}, {...
# 6552  [{'reviewer': 'rooprect', 'rating': None}, {'r...
# 6616  [{'reviewer': 'chron', 'rating': '10'}, {'revi...
# 6982  [{'reviewer': 'Nazi_Fighter_David', 'rating': ...
# 7276  [{'reviewer': 'edwagreen', 'rating': '8'}, {'r...
# 7370  [{'reviewer': 'uds3', 'rating': None}, {'revie...
#
#                              color  \
# 111                      ['Color']
# 132                      ['Color']
# 246                      ['Color']
# 3669  ['Color', 'Black and White']
# 3730                     ['Color']
# 6552                            []
# 6616                     ['Color']
# 6982                     ['Color']
# 7276                     ['Color']
# 7370                     ['Color']
#
#                                                  camera  \
# 111   ['Arri Alexa Studio, Hawk V-Lite and V-Plus Le...
# 132   ['Panavision Panaflex Millennium XL2, Panavisi...
# 246   ['Arri Alexa XT, Hawk V-Lite and V-Series Lens...
# 3669  ['Arri Alexa XT, Zeiss Master Prime and Angeni...
# 3730                                                 []
# 6552  ['Panavision Panaflex Platinum, Panavision Pri...
# 6616    ['Moviecam Compact, Cooke Xtal Express Lenses']
# 6982                  ['Panavision Cameras and Lenses']
# 7276                  ['Panavision Cameras and Lenses']
# 7370                   ['Arriflex Cameras, JDC Lenses']
#
#                                              laboratory  \
# 111   ['DeLuxe, Hollywood (CA), USA', 'Technicolor, ...
# 132   ['Cineworks, New Orleans (LA), USA', 'Technico...
# 246   ['FotoKem Laboratory, Burbank (CA), USA', 'Tec...
# 3669                                                 []
# 3730                                                 []
# 6552  ['DeLuxe, Hollywood (CA), USA', 'Technicolor, ...
# 6616                    ['DeLuxe, Hollywood (CA), USA']
# 6982               ['Technicolor, Hollywood (CA), USA']
# 7276               ['Technicolor, Hollywood (CA), USA']
# 7370               ['Technicolor, Hollywood (CA), USA']
#
#                            film_length             negative_format  \
# 111   ['3,156 m', '3,167 m (6 reels)']           ['Codex ARRIRAW']
# 132                        ['2,754 m']                   ['35 mm']
# 246                                 []           ['Codex ARRIRAW']
# 3669                                []  ['AXSM', 'Codex', 'Video']
# 3730                                []                          []
# 6552                       ['2,939 m']                   ['35 mm']
# 6616                       ['6 reels']                   ['35 mm']
# 6982                                []                   ['35 mm']
# 7276            ['2,580 m', '2,648 m']                   ['35 mm']
# 7370                                []                   ['35 mm']
#
#                                 cinematographic_process  \
# 111              ['Digital Intermediate', 'Hawk Scope']
# 132                ['Digital Intermediate', 'Super 35']
# 246              ['Digital Intermediate', 'Hawk Scope']
# 3669  ['ARRIRAW', 'Digital Intermediate', 'F55 RAW',...
# 3730                                                 []
# 6552               ['Digital Intermediate', 'Super 35']
# 6616                                    ['J-D-C Scope']
# 6982                                     ['Panavision']
# 7276               ['Digital Intermediate', 'Super 35']
# 7370                                       ['Super 35']
#
#         printed_film_format  \
# 111   ['35 mm', 'D-Cinema']
# 132   ['35 mm', 'D-Cinema']
# 246   ['35 mm', 'D-Cinema']
# 3669           ['D-Cinema']
# 3730                     []
# 6552  ['35 mm', 'D-Cinema']
# 6616              ['35 mm']
# 6982              ['35 mm']
# 7276              ['35 mm']
# 7370              ['35 mm']
#
#                                       review_site_names  \
# 111   ['RogerEbert.com [Richard Roeper]', 'ReelViews...
# 132   ['rogerebert.com [Roger Ebert]', 'ReelViews [J...
# 246   ['Roger Ebert [Susan Wloszczyna]', 'New York T...
# 3669  ['ReelViews [James Berardinelli]', 'The New Yo...
# 3730  ['365 Movie Guy [Clark Douglas]', 'A Big Spark...
# 6552  ['rogerebert.com [Roger Ebert]', 'ReelViews [J...
# 6616  ['rogerebert.com [Roger Ebert]', 'Guardian/Obs...
# 6982  ['rogerebert.com [Roger Ebert]', 'ReelViews [J...
# 7276  ['rogerebert.com [Roger Ebert]', 'ReelViews [J...
# 7370  ['rogerebert.com [Roger Ebert]', 'Guardian/Obs...
#
#                                        review_site_urls
# 111   ['http://www.rogerebert.com/reviews/safe-haven...
# 132   ['http://www.rogerebert.com/reviews/the-lucky-...
# 246   ['https://www.rogerebert.com/reviews/the-best-...
# 3669  ['http://www.reelviews.net/reelviews/longest-r...
# 3730  ['http://www.365movieguy.com/review/2016/5/13/...
# 6552  ['http://www.rogerebert.com/reviews/dear-john-...
# 6616  ['http://www.rogerebert.com/reviews/the-notebo...
# 6982  ['http://www.rogerebert.com/reviews/message-in...
# 7276  ['http://www.rogerebert.com/reviews/nights-in-...
# 7370  ['http://www.rogerebert.com/reviews/a-walk-to-...
#
# [10 rows x 47 columns]

# %% [markdown]
# Okay, back to cleaning

# %% [markdown]
# Note to self - consider comparing actors who have also written movies, and see their success rates

# %% [markdown]
# ### -`release_date`- column
# This column explains the release date of the movies

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69419 entries, 0 to 69418
# Data columns (total 47 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   imdb_id                       69419 non-null  object
#  1   title                         69419 non-null  object
#  2   runtime                       69419 non-null  int64
#  3   sound_mix                     69419 non-null  object
#  4   aspect_ratio                  69419 non-null  object
#  5   budget($)                     23548 non-null  float64
#  6   budget_type                   69419 non-null  object
#  7   budget                        27933 non-null  object
#  8   gross_us_canada               12709 non-null  object
#  9   opening_weekend_us_canada     69419 non-null  object
#  10  opening_weekend_revenue(USD)  11750 non-null  float64
#  11  opening_weekend_date          11750 non-null  object
#  12  gross_worldwide_usd           19028 non-null  object
#  13  writers                       21577 non-null  object
#  14  release_date                  65652 non-null  object
#  15  countries_of_origin           69419 non-null  object
#  16  official_sites                69419 non-null  object
#  17  director                      68036 non-null  object
#  18  stars                         69419 non-null  object
#  19  user_reviews                  45662 non-null  object
#  20  critic_reviews                39708 non-null  object
#  21  metascore                     12677 non-null  float64
#  22  languages                     69419 non-null  object
#  23  also_known_as                 40673 non-null  object
#  24  filming_locations             48982 non-null  object
#  25  production_companies          69419 non-null  object
#  26  depth                         69419 non-null  int64
#  27  download_timeout              69419 non-null  float64
#  28  download_slot                 69419 non-null  object
#  29  download_latency              69419 non-null  float64
#  30  redirect_times                69419 non-null  int64
#  31  redirect_ttl                  69419 non-null  int64
#  32  redirect_urls                 69419 non-null  object
#  33  redirect_reasons              69419 non-null  object
#  34  plot_summaries                69419 non-null  object
#  35  synopsis                      66458 non-null  object
#  36  reviews_data                  69419 non-null  object
#  37  reviewer_ratings              69419 non-null  object
#  38  color                         69419 non-null  object
#  39  camera                        69419 non-null  object
#  40  laboratory                    69419 non-null  object
#  41  film_length                   69419 non-null  object
#  42  negative_format               69419 non-null  object
#  43  cinematographic_process       69419 non-null  object
#  44  printed_film_format           69419 non-null  object
#  45  review_site_names             52832 non-null  object
#  46  review_site_urls              52832 non-null  object
# dtypes: float64(5), int64(4), object(38)
# memory usage: 24.9+ MB

# %%
df['release_date'].head(3)
# Out:
# 0     June 8, 2012 (United States)
# 1     July 3, 2013 (United States)
# 2    June 21, 2013 (United States)
# Name: release_date, dtype: object

# %%
# Split 'release_date' column into 'release_date' and 'release_location'
df[['release_date', 'release_location']] = df['release_date'].str.split(' \\(', expand=True)

# %%
# Remove trailing parenthesis from 'release_location'
df['release_location'] = df['release_location'].str.rstrip(')')

# %%
# Convert 'release_date' to datetime
df['release_date'] = pd.to_datetime(df['release_date'])

# %%
# Insert 'release_location' at specific position
df.insert(15, 'release_location', df.pop('release_location'))

# %%
df[['release_date','release_location']].head(3)
# Out:
#   release_date release_location
# 0   2012-06-08    United States
# 1   2013-07-03    United States
# 2   2013-06-21    United States

# %% [markdown]
# ### -`countries_of_origin`- column

# %%
df['countries_of_origin']
# Out:
# 0                  ['United States', 'India']
# 1        ['United States', 'France', 'Japan']
# 2                  ['United States', 'Japan']
# 3                 ['United States', 'France']
# 4                           ['United States']
#                          ...
# 69414                       ['United States']
# 69415                       ['United States']
# 69416                       ['United States']
# 69417                      ['United Kingdom']
# 69418                       ['United States']
# Name: countries_of_origin, Length: 69419, dtype: object

# %%
df['countries_of_origin'] = df['countries_of_origin'].str.replace("[", "").str.replace("]", "").str.replace("'", "")
# Out:
# <ipython-input-241-b688ff3e23b7>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['countries_of_origin'] = df['countries_of_origin'].str.replace("[", "").str.replace("]", "").str.replace("'", "")

# %%
# Remove duplicate entries by converting list to set, then back to string
df['countries_of_origin'] = df['writers'].apply(lambda x: ', '.join(set(x.split(', '))) if isinstance(x, str) else x)

# %%
df['countries_of_origin']
# Out:
# 0                                                      NaN
# 1                                   Ken Daurio, Cinco Paul
# 2                                                      NaN
# 3                        Ken Daurio, Dr. Seuss, Cinco Paul
# 4                                                      NaN
#                                ...
# 69414    Bilal Islam, Sharon Reeves Battle, Karen Walle...
# 69415                Michelle Carmen Gomez, David Palmieri
# 69416                                                  NaN
# 69417                         George Grozier, Jack Vickers
# 69418                          Tyler Cheman, Kristen Skeet
# Name: countries_of_origin, Length: 69419, dtype: object

# %%
# Split the 'writers' column into multiple rows
df_exploded = df.assign(countries_of_origin=df['countries_of_origin'].str.split(', ')).explode('countries_of_origin')

# %%
# Create a new DataFrame that counts the number of movies each writer has made
country_counts = df_exploded['countries_of_origin'].value_counts().reset_index()
country_counts.columns = ['country', 'movie_count']

# %%
# Create a DataFrame that lists the titles each writer has worked on
country_titles = df_exploded.groupby('countries_of_origin')['title'].apply(list).reset_index()
country_titles.columns = ['country', 'movie_titles']

# %%
# Merge the two DataFrames
countries_of_origin_info = pd.merge(country_counts, country_titles, on='country')

# %%
countries_of_origin_info[['country','movie_count']]
# Out:
# Warning: total number of rows (36243) exceeds max_rows (20000). Falling back to pandas display.
#                    country  movie_count
# 0      William Shakespeare           94
# 1             Stephen King           43
# 2           H.P. Lovecraft           26
# 3          Edgar Allan Poe           21
# 4                Joel Coen           20
# ...                    ...          ...
# 36238          Ahmed Farah            1
# 36239          Clark Young            1
# 36240        Derek Goldman            1
# 36241        Brian Ceponis            1
# 36242        Kristen Skeet            1
#
# [36243 rows x 2 columns]

# %% [markdown]
# Note, some extra features to add to this dataset would be:
#
# Looking at the proportion of which each country was done in relationship with other countries.
#
# Also to consider the actors, directors, and writers, to see within each country what factors most strongly impact the gross profit ratio.

# %% [markdown]
# ### -`official_sites`- column

# %%
df['official_sites']
# Out:
# 0        ['https://www.facebook.com/MadagascarMovie', '...
# 1        ['http://www.facebook.com/DespicableMe', 'http...
# 2        ['https://www.facebook.com/PixarMonstersUniver...
# 3        ['http://www.theloraxmovie.com/', 'http://lora...
# 4        ['https://www.facebook.com/OzTheGreatAndPowerf...
#                                ...
# 69414                                                   []
# 69415           ['https://www.facebook.com/claw2themovie']
# 69416                     ['http://www.bigideamovie.com/']
# 69417                     ['https://youtu.be/KkzMrM2l_TI']
# 69418      ['https://www.facebook.com/littlegreenpeople/']
# Name: official_sites, Length: 69419, dtype: object

# %%
# Remove the []

df['official_sites'] = df['official_sites'].str.replace("[", "").str.replace("]", "").str.replace("'", "")
# Out:
# <ipython-input-250-071f6325a256>:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['official_sites'] = df['official_sites'].str.replace("[", "").str.replace("]", "").str.replace("'", "")

# %%
# Replace missing sites with NaN

df['official_sites'] = df['official_sites'].apply(lambda x: np.nan if len(x)==0 else x)

# %%
df['official_sites']
# Out:
# 0        https://www.facebook.com/MadagascarMovie, http...
# 1        http://www.facebook.com/DespicableMe, http://d...
# 2        https://www.facebook.com/PixarMonstersUniversi...
# 3        http://www.theloraxmovie.com/, http://loraxoji...
# 4        https://www.facebook.com/OzTheGreatAndPowerful...
#                                ...
# 69414                                                  NaN
# 69415               https://www.facebook.com/claw2themovie
# 69416                         http://www.bigideamovie.com/
# 69417                         https://youtu.be/KkzMrM2l_TI
# 69418          https://www.facebook.com/littlegreenpeople/
# Name: official_sites, Length: 69419, dtype: object

# %% [markdown]
# ### -`director`- column
#
# Similar changes to the writer's column, except most movies only have 1 director

# %%
df['director']
# Out:
# 0                 Eric Darnell
# 1                Pierre Coffin
# 2                  Dan Scanlon
# 3                 Chris Renaud
# 4                    Sam Raimi
#                  ...
# 69414      Karen Waller-Martin
# 69415    Michelle Carmen Gomez
# 69416                Andy Lang
# 69417             Jack Vickers
# 69418             Tyler Cheman
# Name: director, Length: 69419, dtype: object

# %%
# Split the 'director' column into multiple rows
df_exploded = df.assign(director=df['director'].str.split(', ')).explode('director')

# %%
# Create a new DataFrame that counts the number of movies each director has made
director_counts = df_exploded['director'].value_counts().reset_index()
director_counts.columns = ['director', 'movie_count']

# %%
# Create a DataFrame that lists the titles each director has worked on
director_titles = df_exploded.groupby('director')['title'].apply(list).reset_index()
director_titles.columns = ['director', 'movie_titles']

# %%
# Merge the two DataFrames
director_info = pd.merge(director_counts, director_titles, on='director')

# %%
director_info
# Out:
# Warning: total number of rows (39260) exceeds max_rows (20000). Falling back to pandas display.
#                   director  movie_count  \
# 0          Dustin Ferguson           54
# 1           David DeCoteau           53
# 2            Fred Olen Ray           49
# 3      Michael Fredianelli           47
# 4              Woody Allen           41
# ...                    ...          ...
# 39255          Douglas Law            1
# 39256           Darya Zhuk            1
# 39257   Chuck Morrongiello            1
# 39258        Claire Oakley            1
# 39259         Jack Vickers            1
#
#                                             movie_titles
# 0      [Cocaine Cougar, Night of the Clown, Hell of t...
# 1      [3 Scream Queens, Creepozoids, Sorority Babes ...
# 2      [Christmas in Palm Springs, House of Secrets, ...
# 3      [The Riven, I Die Alone, Black Cat Whiskey, Xe...
# 4      [Blue Jasmine, To Rome with Love, Magic in the...
# ...                                                  ...
# 39255                                    [The Last Sign]
# 39256                                     [Crystal Swan]
# 39257                       [Amityville: Mt. Misery Rd.]
# 39258                                          [Make Up]
# 39259                        [The Best of the Lads 2021]
#
# [39260 rows x 3 columns]

# %%
director_info.to_csv("/content/drive/MyDrive/IMDB Project/Cleaning1/cleaned_data/director_info.csv", encoding = "utf-8")

# %% [markdown]
# ### -`stars`- column

# %%
df.iloc[:,19:20].head()
# Out:
#                                                stars
# 0  ['Ben Stiller', 'Jada Pinkett Smith', 'Chris R...
# 1  ['Steve Carell', 'Kristen Wiig', 'Benjamin Bra...
# 2  ['Billy Crystal', 'John Goodman', 'Steve Busce...
# 3  ['Zac Efron', 'Taylor Swift', 'Danny DeVito', ...
# 4  ['James Franco', 'Michelle Williams', 'Rachel ...

# %%
df['stars'] = df['stars'].str.replace("[", "").str.replace("]", "").str.replace("'", "")
# Out:
# <ipython-input-261-6d70e517b749>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['stars'] = df['stars'].str.replace("[", "").str.replace("]", "").str.replace("'", "")

# %%
df['stars'] = df['stars'].apply(lambda x: ', '.join(set([i.strip() for i in x.split(',')])) if isinstance(x, str) else x)

# %%
# Split the 'stars' column into multiple rows
df_exploded = df.assign(stars=df['stars'].str.split(', ')).explode('stars')

# %%
# Create a new DataFrame that counts the number of movies each star has made
stars_counts = df_exploded['stars'].value_counts().reset_index()
stars_counts.columns = ['stars', 'movie_count']

# %%
# Create a DataFrame that lists the titles each star has worked on
stars_titles = df_exploded.groupby('stars')['title'].apply(list).reset_index()
stars_titles.columns = ['stars', 'movie_titles']

# %%
# Merge the two DataFrames
stars_info = pd.merge(stars_counts, stars_titles, on='stars')

# %%
stars_info
# Out:
# Warning: total number of rows (109180) exceeds max_rows (20000). Falling back to pandas display.
#                      stars  movie_count  \
# 0                                  2723
# 1             Eric Roberts          193
# 2           Michael Madsen          120
# 3             Tom Sizemore          106
# 4             Nicolas Cage           90
# ...                    ...          ...
# 109175         Ian Carlsen            1
# 109176      Jessica Bedell            1
# 109177  Jessica Chancellor            1
# 109178       Beulah Peters            1
# 109179  Ashley Szczerbacki            1
#
#                                              movie_titles
# 0       [All Is Lost, The Oscar Nominated Short Films ...
# 1       [In the Name of God, A New York Heartbeat, The...
# 2       [Ashley, Turn Around Jake, Terrible Angels, Al...
# 3       [Slumber Party Slaughter, The Drunk, 5 Hour Fr...
# 4       [The Croods, Joe, Stolen, The Frozen Ground, R...
# ...                                                   ...
# 109175                                     [The Witching]
# 109176                                     [The Witching]
# 109177                [The Final Level: Escaping Rancala]
# 109178                            [Lake Michigan Monster]
# 109179                              [Little Green People]
#
# [109180 rows x 3 columns]

# %%
stars_info.to_csv("/content/drive/MyDrive/IMDB Project/Cleaning1/cleaned_data/stars_info.csv", encoding = "utf-8")

# %% [markdown]
# ### -user_reviews-

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69419 entries, 0 to 69418
# Data columns (total 48 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   imdb_id                       69419 non-null  object
#  1   title                         69419 non-null  object
#  2   runtime                       69419 non-null  int64
#  3   sound_mix                     69419 non-null  object
#  4   aspect_ratio                  69419 non-null  object
#  5   budget($)                     23548 non-null  float64
#  6   budget_type                   69419 non-null  object
#  7   budget                        27933 non-null  object
#  8   gross_us_canada               12709 non-null  object
#  9   opening_weekend_us_canada     69419 non-null  object
#  10  opening_weekend_revenue(USD)  11750 non-null  float64
#  11  opening_weekend_date          11750 non-null  object
#  12  gross_worldwide_usd           19028 non-null  object
#  13  writers                       21577 non-null  object
#  14  release_date                  65652 non-null  datetime64[ns]
#  15  release_location              65652 non-null  object
#  16  countries_of_origin           21577 non-null  object
#  17  official_sites                38352 non-null  object
#  18  director                      68036 non-null  object
#  19  stars                         69419 non-null  object
#  20  user_reviews                  45662 non-null  object
#  21  critic_reviews                39708 non-null  object
#  22  metascore                     12677 non-null  float64
#  23  languages                     69419 non-null  object
#  24  also_known_as                 40673 non-null  object
#  25  filming_locations             48982 non-null  object
#  26  production_companies          69419 non-null  object
#  27  depth                         69419 non-null  int64
#  28  download_timeout              69419 non-null  float64
#  29  download_slot                 69419 non-null  object
#  30  download_latency              69419 non-null  float64
#  31  redirect_times                69419 non-null  int64
#  32  redirect_ttl                  69419 non-null  int64
#  33  redirect_urls                 69419 non-null  object
#  34  redirect_reasons              69419 non-null  object
#  35  plot_summaries                69419 non-null  object
#  36  synopsis                      66458 non-null  object
#  37  reviews_data                  69419 non-null  object
#  38  reviewer_ratings              69419 non-null  object
#  39  color                         69419 non-null  object
#  40  camera                        69419 non-null  object
#  41  laboratory                    69419 non-null  object
#  42  film_length                   69419 non-null  object
#  43  negative_format               69419 non-null  object
#  44  cinematographic_process       69419 non-null  object
#  45  printed_film_format           69419 non-null  object
#  46  review_site_names             52832 non-null  object
#  47  review_site_urls              52832 non-null  object
# dtypes: datetime64[ns](1), float64(5), int64(4), object(38)
# memory usage: 25.4+ MB

# %%
df['user_reviews']
# Out:
# 0        225
# 1        358
# 2        375
# 3        310
# 4        561
#         ...
# 69414    NaN
# 69415    NaN
# 69416    NaN
# 69417    6.0
# 69418    2.0
# Name: user_reviews, Length: 69419, dtype: object

# %%
def convert_k_to_thousand(val):
    if pd.isnull(val):  # Check if the value is NaN
        return 0  # or replace with any other integer you want
    elif isinstance(val, str) and 'K' in val:
        return int(float(val.replace('K', '')) * 1000)
    else:
        return int(val)

df['user_reviews'] = df['user_reviews'].apply(convert_k_to_thousand)

# %% [markdown]
# ### -`critic_reviews`- column

# %%
df['critic_reviews']
# Out:
# 0        219.0
# 1        323.0
# 2        388.0
# 3        243.0
# 4        511.0
#          ...
# 69414      NaN
# 69415      NaN
# 69416      NaN
# 69417      NaN
# 69418      NaN
# Name: critic_reviews, Length: 69419, dtype: object

# %%
def convert_k_to_thousand(val):
    if pd.isnull(val):  # Check if the value is NaN
        return 0  # or replace with any other integer you want
    elif isinstance(val, str):
        if 'K' in val:
            return int(float(val.replace('K', '')) * 1000)
        else:
            try:
                # Try to convert the string to a float first
                return int(float(val))
            except ValueError:
                # Return NaN if the string can't be converted to a float
                return np.nan
    else:
        return int(val)

# %%
df['critic_reviews'] = df['critic_reviews'].apply(convert_k_to_thousand)

# %% [markdown]
# ### -`metascore`- column

# %%
df['metascore']
# Out:
# 0        60.0
# 1        62.0
# 2        65.0
# 3        46.0
# 4        44.0
#          ...
# 69414     NaN
# 69415     NaN
# 69416     NaN
# 69417     NaN
# 69418     NaN
# Name: metascore, Length: 69419, dtype: float64

# %% [markdown]
# ### -`languages`-

# %%
df['languages']
# Out:
# 0          ['English', 'Spanish']
# 1        ['English', 'Ukrainian']
# 2                     ['English']
# 3                     ['English']
# 4                     ['English']
#                    ...
# 69414                 ['English']
# 69415                 ['English']
# 69416                 ['English']
# 69417                 ['English']
# 69418                 ['English']
# Name: languages, Length: 69419, dtype: object

# %%
df['languages'] = df['languages'].str.replace("[", "").str.replace("]", "").str.replace("'", "");
# Out:
# <ipython-input-277-ed5564aa2a82>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['languages'] = df['languages'].str.replace("[", "").str.replace("]", "").str.replace("'", "");

# %% [markdown]
# ### `-filming locations-`

# %%
df['filming_locations']
# Out:
# 0                                Glendale, California, USA
# 1                                                      NaN
# 2        Walt Disney Animation Studios - 2100 Riverside...
# 3                                                      NaN
# 4        Michigan Motion Picture Studios, 1999 Centerpo...
#                                ...
# 69414                      Philadelphia, Pennsylvania, USA
# 69415                                Amenia, New York, USA
# 69416                                                  NaN
# 69417                                                  NaN
# 69418                                                  NaN
# Name: filming_locations, Length: 69419, dtype: object

# %%
df.iloc[:,25:26].head(20)
# Out:
#                                     filming_locations
# 0                           Glendale, California, USA
# 1                                                 NaN
# 2   Walt Disney Animation Studios - 2100 Riverside...
# 3                                                 NaN
# 4   Michigan Motion Picture Studios, 1999 Centerpo...
# 5                     Tenerife, Canary Islands, Spain
# 6                 Vancouver, British Columbia, Canada
# 7                                                 NaN
# 8                         Emeryville, California, USA
# 9   Georgia World Congress Center, Atlanta, Georgi...
# 10  Walt Disney Feature Animation - 500 S. Buena V...
# 11              Esplanade, Boston, Massachusetts, USA
# 12                        Greenwich, Connecticut, USA
# 13            Paradise, Glenorchy, Otago, New Zealand
# 14  Kaufman Astoria Studios - 3412 36th Street, As...
# 15                      Skógarfoss Waterfall, Iceland
# 16                                      Norway, Norge
# 17  Sony Pictures Studios - 10202 W. Washington Bl...
# 18                         Boston, Massachusetts, USA
# 19                       Albuquerque, New Mexico, USA

# %% [markdown]
# Nothing to do here, next

# %% [markdown]
# ### -`production_companies`-

# %%
df.iloc[:,26:27].head(20)
# Out:
#                                  production_companies
# 0   ['DreamWorks Animation', 'Pacific Data Images ...
# 1   ['Universal Pictures', 'Illumination Entertain...
# 2   ['Walt Disney Pictures', 'Pixar Animation Stud...
# 3   ['Universal Pictures', 'Illumination Entertain...
# 4              ['Walt Disney Pictures', 'Roth Films']
# 5   ['Universal Pictures', 'Relativity Media', 'Or...
# 6   ['Summit Entertainment', 'Temple Hill Entertai...
# 7                            ['DreamWorks Animation']
# 8   ['Walt Disney Pictures', 'Pixar Animation Stud...
# 9                        ['Color Force', 'Lionsgate']
# 10  ['Walt Disney Animation Studios', 'Walt Disney...
# 11  ['Universal Pictures', 'Media Rights Capital (...
# 12  ['Blue Sky Studios', 'FortyFour Studios', 'Twe...
# 13  ['Metro-Goldwyn-Mayer (MGM)', 'New Line Cinema...
# 14  ['Columbia Pictures', 'Hemisphere Media Capita...
# 15         ['Marvel Studios', 'Walt Disney Pictures']
# 16  ['Walt Disney Animation Studios', 'Walt Disney...
# 17  ['Columbia Pictures', 'Sony Pictures Animation...
# 18  ['Twentieth Century Fox', 'Chernin Entertainme...
# 19  ['New Line Cinema', 'Newman/Tooley Films', 'Sl...

# %%
df['production_companies'] = df['production_companies'].str.replace("[", "").str.replace("]", "").str.replace("'", "");
# Out:
# <ipython-input-281-2cb9502a73e9>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['production_companies'] = df['production_companies'].str.replace("[", "").str.replace("]", "").str.replace("'", "");

# %% [markdown]
# MDM Function

# %%
# Split the 'production_companies' column into multiple rows
df_exploded = df.assign(production_companies=df['production_companies'].str.split(', ')).explode('production_companies')

# %%
# Create a new DataFrame that counts the number of movies each writer has made
production_companies_counts = df_exploded['production_companies'].value_counts().reset_index()
production_companies_counts.columns = ['production_companies', 'movie_count']

# %%
# Create a DataFrame that lists the titles each writer has worked on
production_companies_titles = df_exploded.groupby('production_companies')['title'].apply(list).reset_index()
production_companies_titles.columns = ['production_companies', 'movie_titles']

# %%
# Merge the two DataFrames
production_companies_info = pd.merge(production_companies_counts, production_companies_titles, on='production_companies')

# %%
production_companies_info
# Out:
# Warning: total number of rows (56667) exceeds max_rows (20000). Falling back to pandas display.
#          production_companies  movie_count  \
# 0                                     7261
# 1          Universal Pictures          523
# 2                Warner Bros.          508
# 3           Columbia Pictures          436
# 4          Paramount Pictures          427
# ...                       ...          ...
# 56662  Luminary Figures Group            1
# 56663   Cali Bangz Production            1
# 56664     Doomsday Initiative            1
# 56665     Eagle Ridge Studios            1
# 56666  "ShePower Productions"            1
#
#                                             movie_titles
# 0      [Opposite Blood, Final: The Rapture, Roaming, ...
# 1      [Despicable Me 2, The Lorax, Fast & Furious 6,...
# 2      [Argo, The Great Gatsby, Gravity, 300: Rise of...
# 3      [Men in Black 3, Hotel Transylvania, The Amazi...
# 4      [Iron Man 3, World War Z, Star Trek Into Darkn...
# ...                                                  ...
# 56662                                 [Slapped Straight]
# 56663                                       [C.R.E.A.M.]
# 56664                              [He's Dead & So Am I]
# 56665                                 [Trail of Justice]
# 56666                                [The Road to Truth]
#
# [56667 rows x 3 columns]

# %%
production_companies_info.to_csv("/content/drive/MyDrive/IMDB Project/Cleaning1/cleaned_data/production_companies_info.csv", encoding = "utf-8")

# %% [markdown]
# ### `-depth-`

# %%
df.iloc[:,27:28].head(20)
# Out:
#     depth
# 0      12
# 1      18
# 2      18
# 3      16
# 4      26
# 5      26
# 6      19
# 7      15
# 8      27
# 9      35
# 10     23
# 11     32
# 12     10
# 13     44
# 14     21
# 15     37
# 16     54
# 17     15
# 18     23
# 19     23

# %% [markdown]
# # **Cleaning Columns Part 2: User Reviews, Unstructured Data, and Technical Details**
#
# This section continues the cleaning process with a focus on handling more intricate data details.
#
# ##### **Handling User and Critic Reviews**
# - Convert and clean the columns related to user reviews and critic reviews.
#
# ##### **Processing Unstructured Data**
# - Clean and process textual data such as plot summaries, synopsis, and other unstructured data.
#
# ##### **Cleaning Technical Details**
# - Address details like color, camera, laboratory, film length, negative format, cinematographic process, and printed film format.
#
# ##### **Working with Production Companies**
# - Create detailed views of production companies, capturing their projects and affiliations.
#
# ##### **Additional Cleaning Steps**
# - Perform any other necessary cleaning tasks, such as handling missing values, normalizing features, or dealing with outlier values.

# %% [markdown]
# The next part deals with the more difficult type of data: User reviews. Each movie has a lot of different user reviews, and it is saved into a dictionary format, along with their rating for the movie, name and actual review

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69419 entries, 0 to 69418
# Data columns (total 48 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   imdb_id                       69419 non-null  object
#  1   title                         69419 non-null  object
#  2   runtime                       69419 non-null  int64
#  3   sound_mix                     69419 non-null  object
#  4   aspect_ratio                  69419 non-null  object
#  5   budget($)                     23548 non-null  float64
#  6   budget_type                   69419 non-null  object
#  7   budget                        27933 non-null  object
#  8   gross_us_canada               12709 non-null  object
#  9   opening_weekend_us_canada     69419 non-null  object
#  10  opening_weekend_revenue(USD)  11750 non-null  float64
#  11  opening_weekend_date          11750 non-null  object
#  12  gross_worldwide_usd           19028 non-null  object
#  13  writers                       21577 non-null  object
#  14  release_date                  65652 non-null  datetime64[ns]
#  15  release_location              65652 non-null  object
#  16  countries_of_origin           21577 non-null  object
#  17  official_sites                38352 non-null  object
#  18  director                      68036 non-null  object
#  19  stars                         69419 non-null  object
#  20  user_reviews                  69419 non-null  int64
#  21  critic_reviews                69419 non-null  int64
#  22  metascore                     12677 non-null  float64
#  23  languages                     69419 non-null  object
#  24  also_known_as                 40673 non-null  object
#  25  filming_locations             48982 non-null  object
#  26  production_companies          69419 non-null  object
#  27  depth                         69419 non-null  int64
#  28  download_timeout              69419 non-null  float64
#  29  download_slot                 69419 non-null  object
#  30  download_latency              69419 non-null  float64
#  31  redirect_times                69419 non-null  int64
#  32  redirect_ttl                  69419 non-null  int64
#  33  redirect_urls                 69419 non-null  object
#  34  redirect_reasons              69419 non-null  object
#  35  plot_summaries                69419 non-null  object
#  36  synopsis                      66458 non-null  object
#  37  reviews_data                  69419 non-null  object
#  38  reviewer_ratings              69419 non-null  object
#  39  color                         69419 non-null  object
#  40  camera                        69419 non-null  object
#  41  laboratory                    69419 non-null  object
#  42  film_length                   69419 non-null  object
#  43  negative_format               69419 non-null  object
#  44  cinematographic_process       69419 non-null  object
#  45  printed_film_format           69419 non-null  object
#  46  review_site_names             52832 non-null  object
#  47  review_site_urls              52832 non-null  object
# dtypes: datetime64[ns](1), float64(5), int64(6), object(36)
# memory usage: 25.4+ MB

# %% [markdown]
# ### `-plot_summaries-`

# %% [markdown]
# `plot_summaries` is a very unstructured data source, it contains a writeup of the plot of each movie. The goal now is to export the plot summary into a seperate dataframe, and then save it for one-hot or count vectorizing.

# %%
df.iloc[:,35:36]
# Out:
# Warning: total number of rows (69419) exceeds max_rows (20000). Falling back to pandas display.
#                                           plot_summaries
# 0      ['The Madagascar animals join a struggling Eur...
# 1      ["When Gru, the world's most super-bad turned ...
# 2      ['A look at the relationship between Mike Wazo...
# 3      ['A 12-year-old boy searches for the one thing...
# 4      ['A small-time magician is swept away to an en...
# ...                                                  ...
# 69414  ['A young mother is forced to give up her four...
# 69415  ["A writer begins to encounter a series of une...
# 69416  ["Jake Brayburg has a problem. He has to come ...
# 69417  ['The Best Of The Lads 2021 is the epic finale...
# 69418  ['A lone survivor of a crash on the alien worl...
#
# [69419 rows x 1 columns]

# %%
new_df = df[['imdb_id','metascore','languages','production_companies','budget($)', 'title', 'plot_summaries']].copy()

# %%
new_df
# Out:
# Warning: total number of rows (69419) exceeds max_rows (20000). Falling back to pandas display.
#           imdb_id  metascore           languages  \
# 0       tt1277953       60.0    English, Spanish
# 1       tt1690953       62.0  English, Ukrainian
# 2       tt1453405       65.0             English
# 3       tt1482459       46.0             English
# 4       tt1623205       44.0             English
# ...           ...        ...                 ...
# 69414   tt8726540        NaN             English
# 69415  tt14102720        NaN             English
# 69416   tt1821636        NaN             English
# 69417  tt16293944        NaN             English
# 69418  tt11765792        NaN             English
#
#                                     production_companies    budget($)  \
# 0        DreamWorks Animation, Pacific Data Images (PDI)  145000000.0
# 1         Universal Pictures, Illumination Entertainment   76000000.0
# 2          Walt Disney Pictures, Pixar Animation Studios  200000000.0
# 3      Universal Pictures, Illumination Entertainment...   70000000.0
# 4                       Walt Disney Pictures, Roth Films  215000000.0
# ...                                                  ...          ...
# 69414  She-Power Productions, Cota Production Studio,...      50000.0
# 69415                                                          1500.0
# 69416                Really Really Big Show Entertaiment          NaN
# 69417                                                             NaN
# 69418                                                          6000.0
#
#                                     title  \
# 0      Madagascar 3: Europe's Most Wanted
# 1                         Despicable Me 2
# 2                     Monsters University
# 3                               The Lorax
# 4               Oz the Great and Powerful
# ...                                   ...
# 69414                   The Road to Truth
# 69415                Claw 2: Blood Legacy
# 69416                        The Big Idea
# 69417           The Best of the Lads 2021
# 69418                 Little Green People
#
#                                           plot_summaries
# 0      ['The Madagascar animals join a struggling Eur...
# 1      ["When Gru, the world's most super-bad turned ...
# 2      ['A look at the relationship between Mike Wazo...
# 3      ['A 12-year-old boy searches for the one thing...
# 4      ['A small-time magician is swept away to an en...
# ...                                                  ...
# 69414  ['A young mother is forced to give up her four...
# 69415  ["A writer begins to encounter a series of une...
# 69416  ["Jake Brayburg has a problem. He has to come ...
# 69417  ['The Best Of The Lads 2021 is the epic finale...
# 69418  ['A lone survivor of a crash on the alien worl...
#
# [69419 rows x 7 columns]

# %%
new_df.to_csv("/content/drive/MyDrive/IMDB Project/Cleaning1/cleaned_data/plot_summaries_languages_companies_budget_ids.csv", encoding = "utf-8")

# %% [markdown]
# ### -`synopsis-`

# %%
df.iloc[:,36:37].head()
# Out:
#                                             synopsis
# 0  The Madagascar animals join a struggling Europ...
# 1  When Gru, the world's most super-bad turned su...
# 2  Michael "Mike" Wazowski, a six-year-old monste...
# 3  A 12-year-old boy searches for the one thing t...
# 4  A small-time magician is swept away to an ench...

# %% [markdown]
# ### `-review_data_-`

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69419 entries, 0 to 69418
# Data columns (total 48 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   imdb_id                       69419 non-null  object
#  1   title                         69419 non-null  object
#  2   runtime                       69419 non-null  int64
#  3   sound_mix                     69419 non-null  object
#  4   aspect_ratio                  69419 non-null  object
#  5   budget($)                     23548 non-null  float64
#  6   budget_type                   69419 non-null  object
#  7   budget                        27933 non-null  object
#  8   gross_us_canada               12709 non-null  object
#  9   opening_weekend_us_canada     69419 non-null  object
#  10  opening_weekend_revenue(USD)  11750 non-null  float64
#  11  opening_weekend_date          11750 non-null  object
#  12  gross_worldwide_usd           19028 non-null  object
#  13  writers                       21577 non-null  object
#  14  release_date                  65652 non-null  datetime64[ns]
#  15  release_location              65652 non-null  object
#  16  countries_of_origin           21577 non-null  object
#  17  official_sites                38352 non-null  object
#  18  director                      68036 non-null  object
#  19  stars                         69419 non-null  object
#  20  user_reviews                  69419 non-null  int64
#  21  critic_reviews                69419 non-null  int64
#  22  metascore                     12677 non-null  float64
#  23  languages                     69419 non-null  object
#  24  also_known_as                 40673 non-null  object
#  25  filming_locations             48982 non-null  object
#  26  production_companies          69419 non-null  object
#  27  depth                         69419 non-null  int64
#  28  download_timeout              69419 non-null  float64
#  29  download_slot                 69419 non-null  object
#  30  download_latency              69419 non-null  float64
#  31  redirect_times                69419 non-null  int64
#  32  redirect_ttl                  69419 non-null  int64
#  33  redirect_urls                 69419 non-null  object
#  34  redirect_reasons              69419 non-null  object
#  35  plot_summaries                69419 non-null  object
#  36  synopsis                      66458 non-null  object
#  37  reviews_data                  69419 non-null  object
#  38  reviewer_ratings              69419 non-null  object
#  39  color                         69419 non-null  object
#  40  camera                        69419 non-null  object
#  41  laboratory                    69419 non-null  object
#  42  film_length                   69419 non-null  object
#  43  negative_format               69419 non-null  object
#  44  cinematographic_process       69419 non-null  object
#  45  printed_film_format           69419 non-null  object
#  46  review_site_names             52832 non-null  object
#  47  review_site_urls              52832 non-null  object
# dtypes: datetime64[ns](1), float64(5), int64(6), object(36)
# memory usage: 25.4+ MB

# %%
review_df = df[['imdb_id', 'title', 'reviews_data']].copy()

# %%
review_df.to_csv("/content/drive/MyDrive/IMDB Project/Cleaning1/cleaned_data/reviews_and_rating_and_ids.csv", encoding = "utf-8")

# %% [markdown]
# ## Part 1 Continued

# %%
df.iloc[:,39:46].head(10)
# Out:
#                           color  \
# 0                     ['Color']
# 1                     ['Color']
# 2                     ['Color']
# 3                     ['Color']
# 4  ['Color', 'Black and White']
# 5                     ['Color']
# 6                     ['Color']
# 7                     ['Color']
# 8                     ['Color']
# 9                     ['Color']
#
#                                               camera  \
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4              ['Red Epic, Panavision Primo Lenses']
# 5  ['Arricam LT, Zeiss Ultra Prime and Angenieux ...
# 6  ['Arricam ST, Zeiss Ultra Prime and Angenieux ...
# 7                                                 []
# 8                                                 []
# 9  ['Arriflex 435, Panavision Primo, C- and E-Ser...
#
#                                           laboratory  \
# 0                          ['DeLuxe', 'Technicolor']
# 1  ['DeLuxe', 'EFILM Digital Laboratories, Hollyw...
# 2                    ['DeLuxe, Hollywood (CA), USA']
# 3                                ['DeLuxe', 'EFilm']
# 4  ['Company 3, Los Angeles (CA), USA', 'DeLuxe, ...
# 5  ['DeLuxe, Hollywood (CA), USA', 'EFILM Digital...
# 6  ['EFILM Digital Laboratories, Hollywood (CA), ...
# 7                    ['DeLuxe, Hollywood (CA), USA']
# 8                    ['DeLuxe, Hollywood (CA), USA']
# 9  ['DeLuxe, Hollywood (CA), USA', 'EFILM Digital...
#
#                         film_length           negative_format  \
# 0                       ['2,537 m']               ['Digital']
# 1  ['2,673 m', '2,685 m (5 reels)']               ['Digital']
# 2             ['2,843 m (6 reels)']               ['Digital']
# 3            ['2,600 m', '4,285 m']               ['Digital']
# 4             ['3,575 m (7 reels)']  ['35 mm', 'Redcode RAW']
# 5             ['3,565 m (8 reels)']                 ['35 mm']
# 6  ['3,137 m', '3,156 m (6 reels)']                 ['35 mm']
# 7                                []               ['Digital']
# 8  ['2,537 m', '2,820 m (6 reels)']               ['Digital']
# 9  ['3,982 m', '4,007 m (7 reels)']        ['35 mm', '65 mm']
#
#                              cinematographic_process  \
# 0                ['Digital', 'Digital Intermediate']
# 1            ['Digital 3-D', 'Digital Intermediate']
# 2            ['Digital 3-D', 'Digital Intermediate']
# 3            ['Digital 3-D', 'Digital Intermediate']
# 4            ['Digital Intermediate', 'Redcode RAW']
# 5               ['Digital Intermediate', 'Super 35']
# 6               ['Digital Intermediate', 'Super 35']
# 7  ['CinemaScope', 'Digital 3-D', 'Digital Interm...
# 8                ['Digital', 'Digital Intermediate']
# 9  ['Digital Intermediate', 'IMAX', 'Panavision',...
#
#               printed_film_format
# 0           ['35 mm', 'D-Cinema']
# 1           ['35 mm', 'D-Cinema']
# 2           ['35 mm', 'D-Cinema']
# 3           ['35 mm', 'D-Cinema']
# 4  ['35 mm', '70 mm', 'D-Cinema']
# 5           ['35 mm', 'D-Cinema']
# 6           ['35 mm', 'D-Cinema']
# 7           ['35 mm', 'D-Cinema']
# 8           ['35 mm', 'D-Cinema']
# 9  ['35 mm', '70 mm', 'D-Cinema']

# %% [markdown]
# ### `-color`-

# %%
df['color'] = df['color'].str.replace("[", "").str.replace("]", "").str.replace("'", "")
# Out:
# <ipython-input-299-792b9c53b167>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['color'] = df['color'].str.replace("[", "").str.replace("]", "").str.replace("'", "")

# %% [markdown]
# ### -`camera-`

# %%
df['camera'] = df['camera'].str.replace("[", "").str.replace("]", "").str.replace("'", "")
# Out:
# <ipython-input-300-4c99a0d93f50>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['camera'] = df['camera'].str.replace("[", "").str.replace("]", "").str.replace("'", "")

# %% [markdown]
# ### -`laboratory-`

# %%
df['laboratory'] = df['laboratory'].str.replace("[", "").str.replace("]", "").str.replace("'", "")
# Out:
# <ipython-input-301-5951d706a7cf>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['laboratory'] = df['laboratory'].str.replace("[", "").str.replace("]", "").str.replace("'", "")

# %% [markdown]
# ### -`film_length-`

# %%
df['film_length'] = df['film_length'].str.replace("[", "").str.replace("]", "").str.replace("'", "")
# Out:
# <ipython-input-302-a7585b93a6bb>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['film_length'] = df['film_length'].str.replace("[", "").str.replace("]", "").str.replace("'", "")

# %% [markdown]
# ### `-negative_format`

# %%
df['negative_format'] = df['negative_format'].str.replace("[", "").str.replace("]", "").str.replace("'", "")
# Out:
# <ipython-input-303-2cb29866a734>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['negative_format'] = df['negative_format'].str.replace("[", "").str.replace("]", "").str.replace("'", "")

# %% [markdown]
# ### `-cinematographic_process-`

# %%
df['cinematographic_process'] = df['cinematographic_process'].str.replace("[", "").str.replace("]", "").str.replace("'", "")
# Out:
# <ipython-input-304-1d6ff6762c44>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['cinematographic_process'] = df['cinematographic_process'].str.replace("[", "").str.replace("]", "").str.replace("'", "")

# %% [markdown]
# ###`-printed_film_format-`

# %%
df['printed_film_format'] = df['printed_film_format'].str.replace("[", "").str.replace("]", "").str.replace("'", "")
# Out:
# <ipython-input-305-ca77c48ed834>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['printed_film_format'] = df['printed_film_format'].str.replace("[", "").str.replace("]", "").str.replace("'", "")

# %% [markdown]
# ## Exporting the data without the reviews

# %%
df_no_reviews = df.copy()

# %%
# Assuming df is your DataFrame
df_no_reviews = df_no_reviews.drop(columns=['reviews_data'])  # This will remove the 'reviews_data' column

# %%
# Now, to sort the DataFrame based on the 'budget' column in descending order (from highest to lowest):
df_no_reviews = df_no_reviews.sort_values(by='budget($)', ascending=False)

# %%
df_no_reviews['budget($)'].head()
# Out:
# 28383    2.000000e+09
# 46788    8.000000e+08
# 27005    3.560000e+08
# 23545    3.500000e+08
# 22799    3.400000e+08
# Name: budget($), dtype: float64

# %%
df_no_reviews.to_csv("/content/drive/MyDrive/IMDB Project/non_review_analysis/data/without_reviews_by_budget.csv", index=False)
