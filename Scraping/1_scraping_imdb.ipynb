# %% [markdown]
# Run this to mount the code:

# %% [markdown]
# ## Mounting

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install scrapy
# Out:
# Collecting scrapy
#   Downloading Scrapy-2.9.0-py2.py3-none-any.whl (277 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 277.2/277.2 kB 3.4 MB/s eta 0:00:00
# Collecting Twisted>=18.9.0 (from scrapy)
#   Downloading Twisted-22.10.0-py3-none-any.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 18.7 MB/s eta 0:00:00
# Requirement already satisfied: cryptography>=3.4.6 in /usr/lib/python3/dist-packages (from scrapy) (3.4.8)
# Collecting cssselect>=0.9.1 (from scrapy)
#   Downloading cssselect-1.2.0-py2.py3-none-any.whl (18 kB)
# Collecting itemloaders>=1.0.1 (from scrapy)
#   Downloading itemloaders-1.1.0-py3-none-any.whl (11 kB)
# Collecting parsel>=1.5.0 (from scrapy)
#   Downloading parsel-1.8.1-py2.py3-none-any.whl (17 kB)
# Collecting pyOpenSSL>=21.0.0 (from scrapy)
#   Downloading pyOpenSSL-23.2.0-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.0/59.0 kB 6.3 MB/s eta 0:00:00
# Collecting queuelib>=1.4.2 (from scrapy)
#   Downloading queuelib-1.6.2-py2.py3-none-any.whl (13 kB)
# Collecting service-identity>=18.1.0 (from scrapy)
#   Downloading service_identity-23.1.0-py3-none-any.whl (12 kB)
# Collecting w3lib>=1.17.0 (from scrapy)
#   Downloading w3lib-2.1.1-py3-none-any.whl (21 kB)
# Collecting zope.interface>=5.1.0 (from scrapy)
#   Downloading zope.interface-6.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (246 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.0/247.0 kB 19.5 MB/s eta 0:00:00
# Collecting protego>=0.1.15 (from scrapy)
#   Downloading Protego-0.2.1-py2.py3-none-any.whl (8.2 kB)
# Collecting itemadapter>=0.1.0 (from scrapy)
#   Downloading itemadapter-0.8.0-py3-none-any.whl (11 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from scrapy) (67.7.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from scrapy) (23.1)
# Collecting tldextract (from scrapy)
#   Downloading tldextract-3.4.4-py3-none-any.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.3/93.3 kB 9.9 MB/s eta 0:00:00
# Requirement already satisfied: lxml>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from scrapy) (4.9.3)
# Collecting PyDispatcher>=2.0.5 (from scrapy)
#   Downloading PyDispatcher-2.0.7-py3-none-any.whl (12 kB)
# Collecting jmespath>=0.9.5 (from itemloaders>=1.0.1->scrapy)
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from protego>=0.1.15->scrapy) (1.16.0)
# Collecting cryptography>=3.4.6 (from scrapy)
#   Downloading cryptography-41.0.2-cp37-abi3-manylinux_2_28_x86_64.whl (4.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 28.4 MB/s eta 0:00:00
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=3.4.6->scrapy) (1.15.1)
# Requirement already satisfied: attrs>=19.1.0 in /usr/local/lib/python3.10/dist-packages (from service-identity>=18.1.0->scrapy) (23.1.0)
# Requirement already satisfied: pyasn1 in /usr/local/lib/python3.10/dist-packages (from service-identity>=18.1.0->scrapy) (0.5.0)
# Requirement already satisfied: pyasn1-modules in /usr/local/lib/python3.10/dist-packages (from service-identity>=18.1.0->scrapy) (0.3.0)
# Collecting constantly>=15.1 (from Twisted>=18.9.0->scrapy)
#   Downloading constantly-15.1.0-py2.py3-none-any.whl (7.9 kB)
# Collecting incremental>=21.3.0 (from Twisted>=18.9.0->scrapy)
#   Downloading incremental-22.10.0-py2.py3-none-any.whl (16 kB)
# Collecting Automat>=0.8.0 (from Twisted>=18.9.0->scrapy)
#   Downloading Automat-22.10.0-py2.py3-none-any.whl (26 kB)
# Collecting hyperlink>=17.1.1 (from Twisted>=18.9.0->scrapy)
#   Downloading hyperlink-21.0.0-py2.py3-none-any.whl (74 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.6/74.6 kB 7.9 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=3.6.5 in /usr/local/lib/python3.10/dist-packages (from Twisted>=18.9.0->scrapy) (4.7.1)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from tldextract->scrapy) (3.4)
# Requirement already satisfied: requests>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from tldextract->scrapy) (2.27.1)
# Collecting requests-file>=1.4 (from tldextract->scrapy)
#   Downloading requests_file-1.5.1-py2.py3-none-any.whl (3.7 kB)
# Requirement already satisfied: filelock>=3.0.8 in /usr/local/lib/python3.10/dist-packages (from tldextract->scrapy) (3.12.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=3.4.6->scrapy) (2.21)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.1.0->tldextract->scrapy) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.1.0->tldextract->scrapy) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.1.0->tldextract->scrapy) (2.0.12)
# Installing collected packages: PyDispatcher, incremental, constantly, zope.interface, w3lib, queuelib, protego, jmespath, itemadapter, hyperlink, cssselect, Automat, Twisted, requests-file, parsel, cryptography, tldextract, service-identity, pyOpenSSL, itemloaders, scrapy
#   Attempting uninstall: cryptography
#     Found existing installation: cryptography 3.4.8
#     Uninstalling cryptography-3.4.8:
#       Successfully uninstalled cryptography-3.4.8
# Successfully installed Automat-22.10.0 PyDispatcher-2.0.7 Twisted-22.10.0 constantly-15.1.0 cryptography-41.0.2 cssselect-1.2.0 hyperlink-21.0.0 incremental-22.10.0 itemadapter-0.8.0 itemloaders-1.1.0 jmespath-1.0.1 parsel-1.8.1 protego-0.2.1 pyOpenSSL-23.2.0 queuelib-1.6.2 requests-file-1.5.1 scrapy-2.9.0 service-identity-23.1.0 tldextract-3.4.4 w3lib-2.1.1 zope.interface-6.0

# %%
# %cd /content/drive/MyDrive/IMDB\ Project/Scraping
# Out:
# /content/drive/MyDrive/IMDB Project/Scraping

# %% [markdown]
# Now I've already navigated to the current folder, time to make my first project ScraPy_Code 1

# %%
# !scrapy startproject ScraPy_Code_1

# %% [markdown]
# Now to navigate to this part and write my new ScraPy spider: `basic_details_scraper.py`

# %%
# %cd /content/drive/MyDrive/IMDB\ Project/Scraping/ScraPy_Code_1/ScraPy_Code_1/spiders
# Out:
# /content/drive/MyDrive/IMDB Project/Scraping/ScraPy_Code_1/ScraPy_Code_1/spiders

# %% [markdown]
# Now to write the scrapy file! Note, this file scrapes basic details from all the movies that show up via this url:
#
# 'https://www.imdb.com/search/title/?title_type=feature&user_rating=5.0,10.0&languages=en'
#
# From the year 1980 to 2023. Since the file was ran on the 19th of July 2023, that's where the dataset will be updated till.
#
# **The list is roughly 60000 titles long.**
#
#
# Note, it does not take movies that fall below 5 stars of overall user rating!

# %%
# %%writefile basic_details_scraper.py
import scrapy
import csv
import os
import logging

class IMDbMovieSpider(scrapy.Spider):
    name = 'imdb_basic_details_spider2'
    base_url = 'https://www.imdb.com/search/title/?title_type=feature&user_rating=1.0,10.0&languages=en&sort=boxoffice_gross_us,desc'
    output_directory = '/content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data'
    os.makedirs(output_directory, exist_ok=True)

    def start_requests(self):

        print("STARTING START REQUESTSSSS\n\n\n")

        # # Loop through 2-year intervals
        # for year in range(1996,2023,2):
        #     start_date = f'{year-1}-01-01'
        #     end_date = f'{year}-12-31'
        #     url = f'{self.base_url}&release_date={start_date},{end_date}&start=1'
        #     output_file = os.path.join(self.output_directory, f'movies_{year-1}_{year}.csv')


        # Set year to 2023
        year = 2023
        start_date = f'{year}-01-01'
        end_date = f'{year}-12-31'
        url = f'{self.base_url}&release_date={start_date},{end_date}&start=1'
        output_file = os.path.join(self.output_directory, f'movies_{year}.csv')


        # Log the URL and output file
        self.log(f'URL: {url}', level=logging.INFO)
        self.log(f'Output file: {output_file}', level=logging.INFO)

        # Write the headers to the file
        with open(output_file, 'w', newline='', encoding='utf-8') as file:
            writer = csv.writer(file, delimiter='|')
            writer.writerow(['Title', 'Gross', 'Details URL', 'Genres'])

        # Send request for each 2-year interval
        yield scrapy.Request(url=url, callback=self.parse, meta={'output_file': output_file, 'start_year': year-1})

    def parse(self, response):
        print("STARTING PARSE \n\n\n\n")

        self.log('Visited %s' % response.url)

        output_file = response.meta['output_file']
        start_year = response.meta['start_year']

        for movie in response.css('div.lister-item'):
            title = movie.css('h3.lister-item-header a::text').get()
            gross = movie.css('p.sort-num_votes-visible span[name="nv"]:last-child::attr(data-value)').get()
            details_url = movie.css('h3.lister-item-header a::attr(href)').get()
            genres = movie.css('span.genre::text').get()



            # Count the number of rows in the file
            with open(output_file, 'r', newline='', encoding='utf-8') as file:
                reader = csv.reader(file, delimiter='|')
                row_count = sum(1 for row in reader)

            # Save to the appropriate CSV file
            with open(output_file, 'a', newline='', encoding='utf-8') as file:
                writer = csv.writer(file, delimiter='|')
                writer.writerow([title, gross, details_url, genres])


            # Print the number of rows saved to the file
            print(f'Saved {row_count} rows to {output_file}')



        # Pagination
        current_start = int(response.url.split('&start=')[1].split('&')[0])

        # Stop if 10000 titles are reached for the current 2-year interval
        if current_start >= 10000:
            return

        # Go to the next page
        next_start = current_start + 50
        next_page = f'{self.base_url}&release_date={start_year}-01-01,{start_year+2}-12-31&start={next_start}'
        yield scrapy.Request(url=next_page, callback=self.parse, meta={'output_file': output_file, 'start_year': start_year})
# Out:
# Writing basic_details_scraper.py

# %%
#Now, to resave this list but order it by the box office

# %% [markdown]
# The ScraPy spider for the first section has been written! Now, to navigate to the original project directory, then run the spider.

# %%
# Navigate to the spiders folder to view the spider codes
# %cd /content/drive/MyDrive/IMDB\ Project/Scraping/ScraPy_Code_1/ScraPy_Code_1/spiders
# !ls
# Out:
# /content/drive/MyDrive/IMDB Project/Scraping/ScraPy_Code_1/ScraPy_Code_1/spiders
# basic_details_scraper2.py  basic_details_scraper.py  __init__.py  __pycache__

# %%
#Now to actually run the spider! The data will be saved  in '/content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data'

# %cd /content/drive/MyDrive/IMDB\ Project/Scraping/ScraPy_Code_1/ScraPy_Code_1/spiders

# !scrapy runspider basic_details_scraper.py
# Out:
# Streaming output truncated to the last 5000 lines.
# Saved 762 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 763 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 764 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 765 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 766 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 767 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 768 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 769 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 770 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 771 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 772 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 773 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 774 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 775 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 776 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 777 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 778 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 779 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 780 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 781 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 782 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 783 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 784 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 785 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 786 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 787 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 788 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 789 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 790 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 791 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 792 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 793 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 794 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 795 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 796 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 797 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 798 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 799 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 800 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# 2023-07-22 17:41:55 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/search/title/?title_type=feature&user_rating=1.0,10.0&languages=en&sort=boxoffice_gross_us,desc&release_date=2022-01-01,2024-12-31&start=801> (referer: https://www.imdb.com/search/title/?title_type=feature&user_rating=1.0,10.0&languages=en&sort=boxoffice_gross_us,desc&release_date=2022-01-01,2024-12-31&start=751)
# STARTING PARSE
#
#
#
#
# 2023-07-22 17:41:56 [imdb_basic_details_spider2] DEBUG: Visited https://www.imdb.com/search/title/?title_type=feature&user_rating=1.0,10.0&languages=en&sort=boxoffice_gross_us,desc&release_date=2022-01-01,2024-12-31&start=801
# Saved 801 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 802 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 803 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 804 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 805 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 806 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 807 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 808 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 809 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 810 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 811 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 812 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 813 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 814 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 815 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 816 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 817 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 818 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 819 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 820 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 821 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 822 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 823 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 824 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 825 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 826 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 827 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 828 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 829 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 830 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 831 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 832 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 833 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 834 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 835 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 836 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 837 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 838 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 839 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 840 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 841 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 842 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 843 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 844 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 845 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 846 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 847 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 848 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 849 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 850 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# 2023-07-22 17:41:57 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/search/title/?title_type=feature&user_rating=1.0,10.0&languages=en&sort=boxoffice_gross_us,desc&release_date=2022-01-01,2024-12-31&start=851> (referer: https://www.imdb.com/search/title/?title_type=feature&user_rating=1.0,10.0&languages=en&sort=boxoffice_gross_us,desc&release_date=2022-01-01,2024-12-31&start=801)
# STARTING PARSE
#
#
#
#
# 2023-07-22 17:41:57 [imdb_basic_details_spider2] DEBUG: Visited https://www.imdb.com/search/title/?title_type=feature&user_rating=1.0,10.0&languages=en&sort=boxoffice_gross_us,desc&release_date=2022-01-01,2024-12-31&start=851
# Saved 851 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 852 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 853 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 854 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 855 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 856 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 857 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 858 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 859 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 860 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 861 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 862 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 863 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 864 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 865 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 866 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 867 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 868 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 869 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 870 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 871 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 872 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 873 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 874 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 875 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 876 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 877 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 878 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 879 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 880 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 881 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 882 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 883 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 884 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 885 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 886 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 887 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 888 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 889 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 890 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 891 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 892 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 893 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 894 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 895 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 896 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 897 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 898 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 899 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 900 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# 2023-07-22 17:41:58 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/search/title/?title_type=feature&user_rating=1.0,10.0&languages=en&sort=boxoffice_gross_us,desc&release_date=2022-01-01,2024-12-31&start=901> (referer: https://www.imdb.com/search/title/?title_type=feature&user_rating=1.0,10.0&languages=en&sort=boxoffice_gross_us,desc&release_date=2022-01-01,2024-12-31&start=851)
# STARTING PARSE
#
#
#
#
# 2023-07-22 17:41:58 [imdb_basic_details_spider2] DEBUG: Visited https://www.imdb.com/search/title/?title_type=feature&user_rating=1.0,10.0&languages=en&sort=boxoffice_gross_us,desc&release_date=2022-01-01,2024-12-31&start=901
# Saved 901 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 902 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 903 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 904 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 905 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 906 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 907 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 908 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 909 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 910 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 911 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 912 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 913 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 914 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 915 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 916 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 917 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 918 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 919 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 920 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 921 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 922 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 923 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 924 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 925 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 926 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 927 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 928 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 929 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 930 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 931 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 932 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 933 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 934 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 935 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 936 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 937 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 938 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 939 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 940 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 941 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 942 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 943 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 944 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 945 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 946 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 947 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 948 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 949 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 950 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# 2023-07-22 17:41:59 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/search/title/?title_type=feature&user_rating=1.0,10.0&languages=en&sort=boxoffice_gross_us,desc&release_date=2022-01-01,2024-12-31&start=951> (referer: https://www.imdb.com/search/title/?title_type=feature&user_rating=1.0,10.0&languages=en&sort=boxoffice_gross_us,desc&release_date=2022-01-01,2024-12-31&start=901)
# STARTING PARSE
#
#
#
#
# 2023-07-22 17:41:59 [imdb_basic_details_spider2] DEBUG: Visited https://www.imdb.com/search/title/?title_type=feature&user_rating=1.0,10.0&languages=en&sort=boxoffice_gross_us,desc&release_date=2022-01-01,2024-12-31&start=951
# Saved 951 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 952 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 953 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 954 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 955 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 956 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 957 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 958 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 959 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 960 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 961 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 962 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 963 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 964 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 965 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 966 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 967 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 968 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 969 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 970 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 971 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 972 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 973 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 974 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 975 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 976 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 977 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 978 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 979 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 980 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 981 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 982 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 983 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 984 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 985 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 986 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 987 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 988 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 989 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 990 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 991 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 992 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 993 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 994 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 995 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 996 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 997 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 998 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 999 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1000 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# 2023-07-22 17:42:00 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/search/title/?title_type=feature&user_rating=1.0,10.0&languages=en&sort=boxoffice_gross_us,desc&release_date=2022-01-01,2024-12-31&start=1001> (referer: https://www.imdb.com/search/title/?title_type=feature&user_rating=1.0,10.0&languages=en&sort=boxoffice_gross_us,desc&release_date=2022-01-01,2024-12-31&start=951)
# STARTING PARSE
#
#
#
#
# 2023-07-22 17:42:01 [imdb_basic_details_spider2] DEBUG: Visited https://www.imdb.com/search/title/?title_type=feature&user_rating=1.0,10.0&languages=en&sort=boxoffice_gross_us,desc&release_date=2022-01-01,2024-12-31&start=1001
# Saved 1001 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1002 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1003 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1004 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1005 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1006 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1007 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1008 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1009 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1010 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1011 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1012 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1013 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1014 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1015 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1016 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1017 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1018 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1019 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1020 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1021 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1022 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1023 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1024 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1025 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1026 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1027 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1028 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1029 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1030 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1031 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1032 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1033 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1034 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1035 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1036 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1037 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1038 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1039 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1040 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1041 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1042 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1043 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1044 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1045 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1046 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1047 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1048 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1049 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1050 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# 2023-07-22 17:42:02 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/search/title/?title_type=feature&user_rating=1.0,10.0&languages=en&sort=boxoffice_gross_us,desc&release_date=2022-01-01,2024-12-31&start=1051> (referer: https://www.imdb.com/search/title/?title_type=feature&user_rating=1.0,10.0&languages=en&sort=boxoffice_gross_us,desc&release_date=2022-01-01,2024-12-31&start=1001)
# STARTING PARSE
#
#
#
#
# 2023-07-22 17:42:02 [imdb_basic_details_spider2] DEBUG: Visited https://www.imdb.com/search/title/?title_type=feature&user_rating=1.0,10.0&languages=en&sort=boxoffice_gross_us,desc&release_date=2022-01-01,2024-12-31&start=1051
# Saved 1051 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1052 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1053 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1054 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1055 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1056 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1057 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1058 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1059 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1060 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1061 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1062 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1063 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1064 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1065 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1066 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1067 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1068 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1069 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1070 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1071 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1072 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1073 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1074 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1075 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1076 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1077 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1078 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1079 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1080 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1081 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1082 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1083 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1084 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1085 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1086 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1087 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1088 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1089 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1090 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1091 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1092 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1093 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1094 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1095 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1096 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1097 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1098 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1099 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1100 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# 2023-07-22 17:42:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/search/title/?title_type=feature&user_rating=1.0,10.0&languages=en&sort=boxoffice_gross_us,desc&release_date=2022-01-01,2024-12-31&start=1101> (referer: https://www.imdb.com/search/title/?title_type=feature&user_rating=1.0,10.0&languages=en&sort=boxoffice_gross_us,desc&release_date=2022-01-01,2024-12-31&start=1051)
# STARTING PARSE
#
#
#
#
# 2023-07-22 17:42:04 [imdb_basic_details_spider2] DEBUG: Visited https://www.imdb.com/search/title/?title_type=feature&user_rating=1.0,10.0&languages=en&sort=boxoffice_gross_us,desc&release_date=2022-01-01,2024-12-31&start=1101
# Saved 1101 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1102 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1103 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1104 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1105 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1106 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1107 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1108 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1109 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1110 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1111 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1112 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1113 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1114 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1115 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1116 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1117 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1118 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1119 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1120 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1121 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1122 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1123 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1124 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1125 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1126 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1127 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1128 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1129 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1130 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1131 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1132 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1133 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1134 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1135 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1136 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1137 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1138 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1139 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1140 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1141 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1142 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 1143 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# ...
# 2023-07-22 17:45:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/search/title/?title_type=feature&user_rating=1.0,10.0&languages=en&sort=boxoffice_gross_us,desc&release_date=2022-01-01,2024-12-31&start=9351> (referer: https://www.imdb.com/search/title/?title_type=feature&user_rating=1.0,10.0&languages=en&sort=boxoffice_gross_us,desc&release_date=2022-01-01,2024-12-31&start=9301)
# STARTING PARSE
#
#
#
#
# 2023-07-22 17:45:06 [imdb_basic_details_spider2] DEBUG: Visited https://www.imdb.com/search/title/?title_type=feature&user_rating=1.0,10.0&languages=en&sort=boxoffice_gross_us,desc&release_date=2022-01-01,2024-12-31&start=9351
# 2023-07-22 17:45:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/search/title/?title_type=feature&user_rating=1.0,10.0&languages=en&sort=boxoffice_gross_us,desc&release_date=2022-01-01,2024-12-31&start=9401> (referer: https://www.imdb.com/search/title/?title_type=feature&user_rating=1.0,10.0&languages=en&sort=boxoffice_gross_us,desc&release_date=2022-01-01,2024-12-31&start=9351)
# STARTING PARSE
#
#
#
#
# 2023-07-22 17:45:06 [imdb_basic_details_spider2] DEBUG: Visited https://www.imdb.com/search/title/?title_type=feature&user_rating=1.0,10.0&languages=en&sort=boxoffice_gross_us,desc&release_date=2022-01-01,2024-12-31&start=9401
# 2023-07-22 17:45:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/search/title/?title_type=feature&user_rating=1.0,10.0&languages=en&sort=boxoffice_gross_us,desc&release_date=2022-01-01,2024-12-31&start=9451> (referer: https://www.imdb.com/search/title/?title_type=feature&user_rating=1.0,10.0&languages=en&sort=boxoffice_gross_us,desc&release_date=2022-01-01,2024-12-31&start=9401)
# STARTING PARSE
#
#
#
#
# 2023-07-22 17:45:06 [imdb_basic_details_spider2] DEBUG: Visited https://www.imdb.com/search/title/?title_type=feature&user_rating=1.0,10.0&languages=en&sort=boxoffice_gross_us,desc&release_date=2022-01-01,2024-12-31&start=9451
# 2023-07-22 17:45:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/search/title/?title_type=feature&user_rating=1.0,10.0&languages=en&sort=boxoffice_gross_us,desc&release_date=2022-01-01,2024-12-31&start=9501> (referer: https://www.imdb.com/search/title/?title_type=feature&user_rating=1.0,10.0&languages=en&sort=boxoffice_gross_us,desc&release_date=2022-01-01,2024-12-31&start=9451)
# STARTING PARSE
#
#
#
#
# 2023-07-22 17:45:07 [imdb_basic_details_spider2] DEBUG: Visited https://www.imdb.com/search/title/?title_type=feature&user_rating=1.0,10.0&languages=en&sort=boxoffice_gross_us,desc&release_date=2022-01-01,2024-12-31&start=9501
# 2023-07-22 17:45:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/search/title/?title_type=feature&user_rating=1.0,10.0&languages=en&sort=boxoffice_gross_us,desc&release_date=2022-01-01,2024-12-31&start=9551> (referer: https://www.imdb.com/search/title/?title_type=feature&user_rating=1.0,10.0&languages=en&sort=boxoffice_gross_us,desc&release_date=2022-01-01,2024-12-31&start=9501)
# STARTING PARSE
#
#
#
#
# 2023-07-22 17:45:07 [imdb_basic_details_spider2] DEBUG: Visited https://www.imdb.com/search/title/?title_type=feature&user_rating=1.0,10.0&languages=en&sort=boxoffice_gross_us,desc&release_date=2022-01-01,2024-12-31&start=9551
# 2023-07-22 17:45:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/search/title/?title_type=feature&user_rating=1.0,10.0&languages=en&sort=boxoffice_gross_us,desc&release_date=2022-01-01,2024-12-31&start=9601> (referer: https://www.imdb.com/search/title/?title_type=feature&user_rating=1.0,10.0&languages=en&sort=boxoffice_gross_us,desc&release_date=2022-01-01,2024-12-31&start=9551)
# STARTING PARSE
#
#
#
#
# 2023-07-22 17:45:07 [imdb_basic_details_spider2] DEBUG: Visited https://www.imdb.com/search/title/?title_type=feature&user_rating=1.0,10.0&languages=en&sort=boxoffice_gross_us,desc&release_date=2022-01-01,2024-12-31&start=9601
# 2023-07-22 17:45:08 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/search/title/?title_type=feature&user_rating=1.0,10.0&languages=en&sort=boxoffice_gross_us,desc&release_date=2022-01-01,2024-12-31&start=9651> (referer: https://www.imdb.com/search/title/?title_type=feature&user_rating=1.0,10.0&languages=en&sort=boxoffice_gross_us,desc&release_date=2022-01-01,2024-12-31&start=9601)
# STARTING PARSE
#
#
#
#
# 2023-07-22 17:45:08 [imdb_basic_details_spider2] DEBUG: Visited https://www.imdb.com/search/title/?title_type=feature&user_rating=1.0,10.0&languages=en&sort=boxoffice_gross_us,desc&release_date=2022-01-01,2024-12-31&start=9651
# 2023-07-22 17:45:08 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/search/title/?title_type=feature&user_rating=1.0,10.0&languages=en&sort=boxoffice_gross_us,desc&release_date=2022-01-01,2024-12-31&start=9701> (referer: https://www.imdb.com/search/title/?title_type=feature&user_rating=1.0,10.0&languages=en&sort=boxoffice_gross_us,desc&release_date=2022-01-01,2024-12-31&start=9651)
# STARTING PARSE
#
#
#
#
# 2023-07-22 17:45:08 [imdb_basic_details_spider2] DEBUG: Visited https://www.imdb.com/search/title/?title_type=feature&user_rating=1.0,10.0&languages=en&sort=boxoffice_gross_us,desc&release_date=2022-01-01,2024-12-31&start=9701
# 2023-07-22 17:45:08 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/search/title/?title_type=feature&user_rating=1.0,10.0&languages=en&sort=boxoffice_gross_us,desc&release_date=2022-01-01,2024-12-31&start=9751> (referer: https://www.imdb.com/search/title/?title_type=feature&user_rating=1.0,10.0&languages=en&sort=boxoffice_gross_us,desc&release_date=2022-01-01,2024-12-31&start=9701)
# STARTING PARSE
#
#
#
#
# 2023-07-22 17:45:08 [imdb_basic_details_spider2] DEBUG: Visited https://www.imdb.com/search/title/?title_type=feature&user_rating=1.0,10.0&languages=en&sort=boxoffice_gross_us,desc&release_date=2022-01-01,2024-12-31&start=9751
# 2023-07-22 17:45:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/search/title/?title_type=feature&user_rating=1.0,10.0&languages=en&sort=boxoffice_gross_us,desc&release_date=2022-01-01,2024-12-31&start=9801> (referer: https://www.imdb.com/search/title/?title_type=feature&user_rating=1.0,10.0&languages=en&sort=boxoffice_gross_us,desc&release_date=2022-01-01,2024-12-31&start=9751)
# STARTING PARSE
#
#
#
#
# 2023-07-22 17:45:09 [imdb_basic_details_spider2] DEBUG: Visited https://www.imdb.com/search/title/?title_type=feature&user_rating=1.0,10.0&languages=en&sort=boxoffice_gross_us,desc&release_date=2022-01-01,2024-12-31&start=9801
# 2023-07-22 17:45:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/search/title/?title_type=feature&user_rating=1.0,10.0&languages=en&sort=boxoffice_gross_us,desc&release_date=2022-01-01,2024-12-31&start=9851> (referer: https://www.imdb.com/search/title/?title_type=feature&user_rating=1.0,10.0&languages=en&sort=boxoffice_gross_us,desc&release_date=2022-01-01,2024-12-31&start=9801)
# STARTING PARSE
#
#
#
#
# 2023-07-22 17:45:09 [imdb_basic_details_spider2] DEBUG: Visited https://www.imdb.com/search/title/?title_type=feature&user_rating=1.0,10.0&languages=en&sort=boxoffice_gross_us,desc&release_date=2022-01-01,2024-12-31&start=9851
# 2023-07-22 17:45:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/search/title/?title_type=feature&user_rating=1.0,10.0&languages=en&sort=boxoffice_gross_us,desc&release_date=2022-01-01,2024-12-31&start=9901> (referer: https://www.imdb.com/search/title/?title_type=feature&user_rating=1.0,10.0&languages=en&sort=boxoffice_gross_us,desc&release_date=2022-01-01,2024-12-31&start=9851)
# STARTING PARSE
#
#
#
#
# 2023-07-22 17:45:09 [imdb_basic_details_spider2] DEBUG: Visited https://www.imdb.com/search/title/?title_type=feature&user_rating=1.0,10.0&languages=en&sort=boxoffice_gross_us,desc&release_date=2022-01-01,2024-12-31&start=9901
# 2023-07-22 17:45:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/search/title/?title_type=feature&user_rating=1.0,10.0&languages=en&sort=boxoffice_gross_us,desc&release_date=2022-01-01,2024-12-31&start=9951> (referer: https://www.imdb.com/search/title/?title_type=feature&user_rating=1.0,10.0&languages=en&sort=boxoffice_gross_us,desc&release_date=2022-01-01,2024-12-31&start=9901)
# STARTING PARSE
#
#
#
#
# 2023-07-22 17:45:10 [imdb_basic_details_spider2] DEBUG: Visited https://www.imdb.com/search/title/?title_type=feature&user_rating=1.0,10.0&languages=en&sort=boxoffice_gross_us,desc&release_date=2022-01-01,2024-12-31&start=9951
# 2023-07-22 17:45:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/search/title/?title_type=feature&user_rating=1.0,10.0&languages=en&sort=boxoffice_gross_us,desc&release_date=2022-01-01,2024-12-31&start=10001> (referer: https://www.imdb.com/search/title/?title_type=feature&user_rating=1.0,10.0&languages=en&sort=boxoffice_gross_us,desc&release_date=2022-01-01,2024-12-31&start=9951)
# STARTING PARSE
#
#
#
#
# 2023-07-22 17:45:10 [imdb_basic_details_spider2] DEBUG: Visited https://www.imdb.com/search/title/?title_type=feature&user_rating=1.0,10.0&languages=en&sort=boxoffice_gross_us,desc&release_date=2022-01-01,2024-12-31&start=10001
# Saved 4388 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 4389 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 4390 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 4391 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 4392 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 4393 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 4394 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 4395 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 4396 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 4397 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 4398 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 4399 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 4400 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 4401 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 4402 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 4403 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 4404 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 4405 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 4406 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 4407 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 4408 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 4409 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 4410 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 4411 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 4412 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 4413 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 4414 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 4415 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 4416 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 4417 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 4418 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 4419 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 4420 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 4421 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 4422 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 4423 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 4424 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 4425 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 4426 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 4427 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 4428 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 4429 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 4430 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 4431 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 4432 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 4433 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 4434 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 4435 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 4436 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# Saved 4437 rows to /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1.1_data/movies_2023.csv
# 2023-07-22 17:45:11 [scrapy.core.engine] INFO: Closing spider (finished)
# 2023-07-22 17:45:11 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 140330,
#  'downloader/request_count': 202,
#  'downloader/request_method_count/GET': 202,
#  'downloader/response_bytes': 55490115,
#  'downloader/response_count': 202,
#  'downloader/response_status_count/200': 202,
#  'elapsed_time_seconds': 211.405881,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2023, 7, 22, 17, 45, 11, 352387),
#  'log_count/DEBUG': 408,
#  'log_count/INFO': 15,
#  'memusage/max': 187363328,
#  'memusage/startup': 109535232,
#  'request_depth_max': 200,
#  'response_received_count': 202,
#  'robotstxt/request_count': 1,
#  'robotstxt/response_count': 1,
#  'robotstxt/response_status_count/200': 1,
#  'scheduler/dequeued': 201,
#  'scheduler/dequeued/memory': 201,
#  'scheduler/enqueued': 201,
#  'scheduler/enqueued/memory': 201,
#  'start_time': datetime.datetime(2023, 7, 22, 17, 41, 39, 946506)}
# 2023-07-22 17:45:11 [scrapy.core.engine] INFO: Spider closed (finished)

# %%
import os

def check_file_exists(file_path):
    if os.path.isfile(file_path):
        print(f"The file '{file_path}' exists.")
    else:
        print(f"The file '{file_path}' does not exist.")

# Use the function to check if your file exists
check_file_exists('/content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_2016_2017.csv')
# Out:
# The file '/content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_2016_2017.csv' exists.

# %% [markdown]
# Alright! Now we have our entire list of movies, some small amounts of detail, and most importantly the movie id, which will be used to guide the more detailed scraper.
#
# But first, we need to concatenate all of these files into 1, the reason why we had to scrape in groups of 2 years is because there is a 10K results limit for each search category.

# %%
import pandas as pd
import glob

# Get a list of all CSV files
csv_files = glob.glob('/content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/*.csv')
csv_files
# Out:
# ['/content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/all_movie_ids_old.csv',
#  '/content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_2014_2015.csv',
#  '/content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_2002_2003.csv',
#  '/content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_2016_2017.csv',
#  '/content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_1992_1993.csv',
#  '/content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_2012_2013.csv',
#  '/content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_2004_2005.csv',
#  '/content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_1996_1997.csv',
#  '/content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_1998_1999.csv',
#  '/content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_1982_1983.csv',
#  '/content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_1986_1987.csv',
#  '/content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_2006_2007.csv',
#  '/content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_2000_2001.csv',
#  '/content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_1994_1995.csv',
#  '/content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_1990_1991.csv',
#  '/content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_1984_1985.csv',
#  '/content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_2010_2011.csv',
#  '/content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_2022_2023.csv',
#  '/content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_1980_1981.csv',
#  '/content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_1988_1989.csv',
#  '/content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_2008_2009.csv',
#  '/content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_2018_2019.csv',
#  '/content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/all_movie_ids2.csv']

# %%
csv_files.remove('/content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/all_movie_ids_old.csv')
csv_files.remove('/content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/all_movie_ids2.csv')

# %%
csv_files
# Out:
# ['/content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_2014_2015.csv',
#  '/content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_2002_2003.csv',
#  '/content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_2016_2017.csv',
#  '/content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_1992_1993.csv',
#  '/content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_2012_2013.csv',
#  '/content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_2004_2005.csv',
#  '/content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_1996_1997.csv',
#  '/content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_1998_1999.csv',
#  '/content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_1982_1983.csv',
#  '/content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_1986_1987.csv',
#  '/content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_2006_2007.csv',
#  '/content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_2000_2001.csv',
#  '/content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_1994_1995.csv',
#  '/content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_1990_1991.csv',
#  '/content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_1984_1985.csv',
#  '/content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_2010_2011.csv',
#  '/content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_2022_2023.csv',
#  '/content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_1980_1981.csv',
#  '/content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_1988_1989.csv',
#  '/content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_2008_2009.csv',
#  '/content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_2018_2019.csv']

# %%
import pandas as pd

# Iterate over each file
for file in csv_files:
    # Read the file
    df = pd.read_csv(file, header = None, nrows=3, sep='|')

    # Display the first row
    print(f"File: {file}")
    print(df)

    # Get the new column names
    new_columns = input("Enter the new column names, comma separated: ")
    new_columns = new_columns.split(",")

    # Read the file again with the new column names
    df = pd.read_csv(file, names=new_columns, header = None, sep='|')

    # Overwrite the original file
    df.to_csv(file, index=False)
# Out:
# File: /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_2014_2015.csv
#                        0                                                  1   \
# 0            Jason Bourne  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 1  Straight Outta Compton  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 2        Star Trek Beyond  https://m.media-amazon.com/images/S/sash/4Fyxw...
#
#                   2           3        4   \
# 0  /title/tt4196776/  (I) (2016)  123 min
# 1  /title/tt1398426/      (2015)  147 min
# 2  /title/tt2660888/      (2016)  122 min
#
#                                         5    6   7   \
# 0           \nAction, Thriller              6.6  58
# 1  \nBiography, Drama, History              7.8  72
# 2  \nAction, Adventure, Sci-Fi              7.0  68
#
#                                                   8   9            10
# 0  The CIA's most dangerous former operative is d... NaN  162,434,410
# 1                                      The rap group NaN  161,197,785
# 2  The crew of the USS Enterprise explores the fu... NaN  158,848,340
# Enter the new column names, comma separated: 'Title', 'image_url', 'details_url', 'date', 'duration', 'genres', 'rating', 'metascore', 'summary', 'votes', 'gross'
# File: /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_2002_2003.csv
#                     0                                                  1   \
# 0  The Bourne Identity  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 1       50 First Dates  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 2           Seabiscuit  https://m.media-amazon.com/images/S/sash/4Fyxw...
#
#                   2       3        4   \
# 0  /title/tt0258463/  (2002)  119 min
# 1  /title/tt0343660/  (2004)   99 min
# 2  /title/tt0329575/  (2003)  140 min
#
#                                         5    6   7   \
# 0  \nAction, Mystery, Thriller              7.9  68
# 1     \nComedy, Drama, Romance              6.8  48
# 2      \nDrama, History, Sport              7.3  72
#
#                                                   8   9            10
# 0  A man is picked up by a fishing boat, bullet-r... NaN  121,661,683
# 1  Henry Roth is a man afraid of commitment until... NaN  120,908,074
# 2  True story of the undersized Depression-era ra... NaN  120,277,854
# Enter the new column names, comma separated: 'Title', 'image_url', 'details_url', 'date', 'duration', 'genres', 'rating', 'metascore', 'summary', 'votes', 'gross'
# File: /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_2016_2017.csv
#                                       0   \
# 0                         Hidden Figures
# 1                     Kong: Skull Island
# 2  Hotel Transylvania 3: Summer Vacation
#
#                                                   1                  2   \
# 0  https://m.media-amazon.com/images/S/sash/4Fyxw...  /title/tt4846340/
# 1  https://m.media-amazon.com/images/S/sash/4Fyxw...  /title/tt3731562/
# 2  https://m.media-amazon.com/images/S/sash/4Fyxw...  /title/tt5220122/
#
#        3        4                                           5    6   7   \
# 0  (2016)  127 min     \nBiography, Drama, History              7.8  74
# 1  (2017)  118 min    \nAction, Adventure, Fantasy              6.6  62
# 2  (2018)   97 min  \nAnimation, Adventure, Comedy              6.3  54
#
#                                                   8   9            10
# 0  The story of a team of female African-American... NaN  169,607,287
# 1  After the Vietnam war, a team of scientists ex... NaN  168,052,812
# 2  Count Dracula and company participate in a cru... NaN  167,510,016
# Enter the new column names, comma separated: 'Title', 'image_url', 'details_url', 'date', 'duration', 'genres', 'rating', 'metascore', 'summary', 'votes', 'gross'
# File: /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_1992_1993.csv
#                     0                                                  1   \
# 0        Cool Runnings  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 1  Legends of the Fall  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 2                 Wolf  https://m.media-amazon.com/images/S/sash/4Fyxw...
#
#                   2       3        4   \
# 0  /title/tt0106611/  (1993)   98 min
# 1  /title/tt0110322/  (1994)  133 min
# 2  /title/tt0111742/  (1994)  125 min
#
#                                         5    6     7   \
# 0  \nAdventure, Comedy, Family              7.0  60.0
# 1        \nDrama, Romance, War              7.5  45.0
# 2     \nDrama, Horror, Romance              6.2   NaN
#
#                                                   8   9           10
# 0  When a Jamaican sprinter is disqualified from ... NaN  68,856,263
# 1  In the early 1900s, three brothers and their f... NaN  66,638,883
# 2  Publisher Will Randall becomes a demon wolf an... NaN  65,012,000
# Enter the new column names, comma separated: 'Title', 'image_url', 'details_url', 'date', 'duration', 'genres', 'rating', 'metascore', 'summary', 'votes', 'gross'
# File: /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_2012_2013.csv
#                   0                                                  1   \
# 0          Divergent  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 1  We're the Millers  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 2          Neighbors  https://m.media-amazon.com/images/S/sash/4Fyxw...
#
#                   2           3        4   \
# 0  /title/tt1840309/      (2014)  139 min
# 1  /title/tt1723121/      (2013)  110 min
# 2  /title/tt2004420/  (I) (2014)   97 min
#
#                                          5    6   7   \
# 0  \nAction, Adventure, Mystery              6.6  48
# 1               \nComedy, Crime              7.0  44
# 2                      \nComedy              6.3  68
#
#                                                   8   9            10
# 0  In a world divided by factions based on virtue... NaN  150,947,895
# 1  A veteran pot dealer creates a fake family as ... NaN  150,394,119
# 2  After they are forced to live next to a frater... NaN  150,157,400
# Enter the new column names, comma separated: 'Title', 'image_url', 'details_url', 'date', 'duration', 'genres', 'rating', 'metascore', 'summary', 'votes', 'gross'
# File: /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_2004_2005.csv
#                                0   \
# 0                    The Break-Up
# 1  A Series of Unfortunate Events
# 2                 Blades of Glory
#
#                                                   1                  2   \
# 0  https://m.media-amazon.com/images/S/sash/4Fyxw...  /title/tt0452594/
# 1  https://m.media-amazon.com/images/S/sash/4Fyxw...  /title/tt0339291/
# 2  https://m.media-amazon.com/images/S/sash/4Fyxw...  /title/tt0445934/
#
#        3        4                                        5    6   7   \
# 0  (2006)  106 min     \nComedy, Drama, Romance              5.8  45
# 1  (2004)  108 min  \nAdventure, Comedy, Family              6.8  62
# 2  (2006)   93 min              \nComedy, Sport              6.3  64
#
#                                                   8   9            10
# 0  In a bid to keep their luxurious condo from th... NaN  118,703,275
# 1  When a massive fire kills their parents, three... NaN  118,627,117
# 2  In 2002, two rival Olympic ice skaters were st... NaN  118,594,548
# Enter the new column names, comma separated: 'Title', 'image_url', 'details_url', 'date', 'duration', 'genres', 'rating', 'metascore', 'summary', 'votes', 'gross'
# File: /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_1996_1997.csv
#                          0   \
# 0         The Mask of Zorro
# 1                   Flubber
# 2  Star Trek: First Contact
#
#                                                   1                  2   \
# 0  https://m.media-amazon.com/images/S/sash/4Fyxw...  /title/tt0120746/
# 1  https://m.media-amazon.com/images/S/sash/4Fyxw...  /title/tt0119137/
# 2  https://m.media-amazon.com/images/S/sash/4Fyxw...  /title/tt0117731/
#
#        3        4                                        5    6   7   \
# 0  (1998)  136 min  \nAction, Adventure, Comedy              6.8  63
# 1  (1997)   93 min     \nComedy, Family, Sci-Fi              5.3  37
# 2  (1996)  111 min   \nAction, Adventure, Drama              7.6  71
#
#                                                   8   9           10
# 0  A young thief seeking revenge for his brother'... NaN  94,095,523
# 1  An absent-minded professor discovers "flubber,... NaN  92,977,226
# 2  The Borg travel back in time intent on prevent... NaN  92,001,027
# Enter the new column names, comma separated: 'Title', 'image_url', 'details_url', 'date', 'duration', 'genres', 'rating', 'metascore', 'summary', 'votes', 'gross'
# File: /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_1998_1999.csv
#                   0                                                  1   \
# 0       Analyze This  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 1        Chicken Run  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 2  Miss Congeniality  https://m.media-amazon.com/images/S/sash/4Fyxw...
#
#                   2       3        4   \
# 0  /title/tt0122933/  (1999)  103 min
# 1  /title/tt0120630/  (2000)   84 min
# 2  /title/tt0212346/  (2000)  109 min
#
#                                            5    6   7   \
# 0                 \nComedy, Crime              6.7  61
# 1  \nAnimation, Adventure, Comedy              7.1  88
# 2         \nAction, Comedy, Crime              6.3  43
#
#                                                   8   9            10
# 0  A comedy about a psychiatrist whose number-one... NaN  106,885,658
# 1  When a cockerel apparently flies into a chicke... NaN  106,834,564
# 2  An F.B.I. Agent must go undercover in the Miss... NaN  106,807,667
# Enter the new column names, comma separated: 'Title', 'image_url', 'details_url', 'date', 'duration', 'genres', 'rating', 'metascore', 'summary', 'votes', 'gross'
# File: /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_1982_1983.csv
#                            0   \
# 0         Conan the Barbarian
# 1  The Sword and the Sorcerer
# 2                    Breakin'
#
#                                                   1                  2   \
# 0  https://m.media-amazon.com/images/S/sash/4Fyxw...  /title/tt0082198/
# 1  https://m.media-amazon.com/images/S/sash/4Fyxw...  /title/tt0084749/
# 2  https://m.media-amazon.com/images/S/sash/4Fyxw...  /title/tt0086998/
#
#        3        4                                         5    6   7   \
# 0  (1982)  129 min  \nAction, Adventure, Fantasy              6.9  43
# 1  (1982)   99 min  \nAction, Adventure, Fantasy              5.4  39
# 2  (1984)   87 min        \nComedy, Drama, Music              5.8  53
#
#                                                   8   9           10
# 0  A young boy, Conan, becomes a slave after his ... NaN  39,565,475
# 1  A mercenary with a three-bladed sword rediscov... NaN  39,103,425
# 2  A struggling young jazz dancer meets up with t... NaN  38,682,707
# Enter the new column names, comma separated: 'Title', 'image_url', 'details_url', 'date', 'duration', 'genres', 'rating', 'metascore', 'summary', 'votes', 'gross'
# File: /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_1986_1987.csv
#                                               0   \
# 0                   Planes, Trains & Automobiles
# 1  A Nightmare on Elm Street 4: The Dream Master
# 2                                          Cobra
#
#                                                   1                  2   \
# 0  https://m.media-amazon.com/images/S/sash/4Fyxw...  /title/tt0093748/
# 1  https://m.media-amazon.com/images/S/sash/4Fyxw...  /title/tt0095742/
# 2  https://m.media-amazon.com/images/S/sash/4Fyxw...  /title/tt0090859/
#
#        3       4                                      5    6   7   \
# 0  (1987)  93 min            \nComedy, Drama              7.6  72
# 1  (1988)  93 min                   \nHorror              5.6  56
# 2  (1986)  87 min  \nAction, Crime, Thriller              5.8  25
#
#                                                   8   9           10
# 0  A Chicago advertising man must struggle to tra... NaN  49,530,280
# 1  Freddy Krueger returns once again to terrorize... NaN  49,369,899
# 2  A tough-on-crime street cop must protect the o... NaN  49,042,224
# Enter the new column names, comma separated: 'Title', 'image_url', 'details_url', 'date', 'duration', 'genres', 'rating', 'metascore', 'summary', 'votes', 'gross'
# File: /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_2006_2007.csv
#                                           0   \
# 0                               The Departed
# 1  Fantastic Four: Rise of the Silver Surfer
# 2                                  Get Smart
#
#                                                   1                  2   \
# 0  https://m.media-amazon.com/images/S/sash/4Fyxw...  /title/tt0407887/
# 1  https://m.media-amazon.com/images/S/sash/4Fyxw...  /title/tt0486576/
# 2  https://m.media-amazon.com/images/S/sash/4Fyxw...  /title/tt0425061/
#
#        3        4                                         5    6   7   \
# 0  (2006)  151 min      \nCrime, Drama, Thriller              8.5  85
# 1  (2007)   92 min  \nAction, Adventure, Fantasy              5.6  45
# 2  (2008)  110 min   \nAction, Adventure, Comedy              6.5  54
#
#                                                   8   9            10
# 0  An undercover cop and a mole in the police att... NaN  132,384,315
# 1  The Fantastic Four learn that they aren't the ... NaN  131,921,738
# 2  Maxwell Smart, a highly intellectual but bumbl... NaN  130,319,208
# Enter the new column names, comma separated: 'Title', 'image_url', 'details_url', 'date', 'duration', 'genres', 'rating', 'metascore', 'summary', 'votes', 'gross'
# File: /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_2000_2001.csv
#                      0                                                  1   \
# 0   The Bourne Identity  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 1  The Sum of All Fears  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 2     Big Momma's House  https://m.media-amazon.com/images/S/sash/4Fyxw...
#
#                   2       3        4   \
# 0  /title/tt0258463/  (2002)  119 min
# 1  /title/tt0164184/  (2002)  124 min
# 2  /title/tt0208003/  (2000)   99 min
#
#                                         5    6   7   \
# 0  \nAction, Mystery, Thriller              7.9  68
# 1    \nAction, Drama, Thriller              6.4  45
# 2      \nAction, Comedy, Crime              5.2  33
#
#                                                   8   9            10
# 0  A man is picked up by a fishing boat, bullet-r... NaN  121,661,683
# 1  CIA analyst Jack Ryan must stop the plans of a... NaN  118,907,036
# 2  In order to protect a beautiful woman and her ... NaN  117,559,438
# Enter the new column names, comma separated: 'Title', 'image_url', 'details_url', 'date', 'duration', 'genres', 'rating', 'metascore', 'summary', 'votes', 'gross'
# File: /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_1994_1995.csv
#                            0   \
# 0      Star Trek: Generations
# 1                  Braveheart
# 2  Ace Ventura: Pet Detective
#
#                                                   1                  2   \
# 0  https://m.media-amazon.com/images/S/sash/4Fyxw...  /title/tt0111280/
# 1  https://m.media-amazon.com/images/S/sash/4Fyxw...  /title/tt0112573/
# 2  https://m.media-amazon.com/images/S/sash/4Fyxw...  /title/tt0109040/
#
#        3        4                                         5    6   7   \
# 0  (1994)  118 min  \nAction, Adventure, Mystery              6.6  55
# 1  (1995)  178 min   \nBiography, Drama, History              8.3  68
# 2  (1994)   86 min                      \nComedy              6.9  37
#
#                                                   8   9           10
# 0  With the help of long presumed dead Captain Ki... NaN  75,668,868
# 1  Scottish warrior William Wallace leads his cou... NaN  75,600,000
# 2  A goofy detective specializing in animals goes... NaN  72,217,000
# Enter the new column names, comma separated: 'Title', 'image_url', 'details_url', 'date', 'duration', 'genres', 'rating', 'metascore', 'summary', 'votes', 'gross'
# File: /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_1990_1991.csv
#                        0                                                  1   \
# 0               Boomerang  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 1              Hot Shots!  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 2  The Godfather Part III  https://m.media-amazon.com/images/S/sash/4Fyxw...
#
#                   2       3        4                                     5   \
# 0  /title/tt0103859/  (1992)  117 min  \nComedy, Drama, Romance
# 1  /title/tt0102059/  (1991)   84 min          \nAction, Comedy
# 2  /title/tt0099674/  (1990)  162 min            \nCrime, Drama
#
#     6   7                                                  8   9           10
# 0  5.6  45  A successful executive and womanizer finds his... NaN  70,100,000
# 1  6.7  61                                        A parody of NaN  69,467,617
# 2  7.6  60  Follows Michael Corleone, now in his 60s, as h... NaN  66,666,062
# Enter the new column names, comma separated: 'Title', 'image_url', 'details_url', 'date', 'duration', 'genres', 'rating', 'metascore', 'summary', 'votes', 'gross'
# File: /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_1984_1985.csv
#                                0   \
# 0                      Pale Rider
# 1           Peggy Sue Got Married
# 2  Poltergeist II: The Other Side
#
#                                                   1                  2   \
# 0  https://m.media-amazon.com/images/S/sash/4Fyxw...  /title/tt0089767/
# 1  https://m.media-amazon.com/images/S/sash/4Fyxw...  /title/tt0091738/
# 2  https://m.media-amazon.com/images/S/sash/4Fyxw...  /title/tt0091778/
#
#        3        4                                     5    6   7   \
# 0  (1985)  115 min          \nDrama, Western              7.3  61
# 1  (1986)  103 min  \nComedy, Drama, Fantasy              6.4  75
# 2  (1986)   91 min                  \nHorror              5.6  49
#
#                                                   8   9           10
# 0                            A mysterious preacher ( NaN  41,410,568
# 1  Peggy Sue faints at a high school reunion. Whe... NaN  41,382,841
# 2  The Freeling family have a new house, but thei... NaN  40,996,665
# Enter the new column names, comma separated: 'Title', 'image_url', 'details_url', 'date', 'duration', 'genres', 'rating', 'metascore', 'summary', 'votes', 'gross'
# File: /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_2010_2011.csv
#                                     0   \
# 0                     Think Like a Man
# 1  Prince of Persia: The Sands of Time
# 2                                  RED
#
#                                                   1                  2   \
# 0  https://m.media-amazon.com/images/S/sash/4Fyxw...  /title/tt1621045/
# 1  https://m.media-amazon.com/images/S/sash/4Fyxw...  /title/tt0473075/
# 2  https://m.media-amazon.com/images/S/sash/4Fyxw...  /title/tt1245526/
#
#        3        4                                         5    6   7   \
# 0  (2012)  122 min             \nComedy, Romance              6.5  51
# 1  (2010)  116 min  \nAction, Adventure, Fantasy              6.6  50
# 2  (2010)  111 min       \nAction, Comedy, Crime              7.0  60
#
#                                                   8   9           10
# 0  Four friends conspire to turn the tables on th... NaN  91,547,205
# 1  A young fugitive prince and princess must stop... NaN  90,759,676
# 2  When his peaceful life is threatened by a high... NaN  90,380,162
# Enter the new column names, comma separated: 'Title', 'image_url', 'details_url', 'date', 'duration', 'genres', 'rating', 'metascore', 'summary', 'votes', 'gross'
# File: /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_2022_2023.csv
#                          0   \
# 0                    Tetris
# 1  Shazam! Fury of the Gods
# 2                   Ghosted
#
#                                                   1                   2   \
# 0  https://m.media-amazon.com/images/S/sash/4Fyxw...  /title/tt12758060/
# 1  https://m.media-amazon.com/images/S/sash/4Fyxw...  /title/tt10151854/
# 2  https://m.media-amazon.com/images/S/sash/4Fyxw...  /title/tt15326988/
#
#            3        4                                        5    6   7   \
# 0      (2023)  118 min  \nBiography, Drama, History              7.4  61
# 1      (2023)  130 min  \nAction, Adventure, Comedy              6.0  47
# 2  (I) (2023)  116 min  \nAction, Adventure, Comedy              5.8  34
#
#                                                   8   9      10
# 0  The story of how one of the world's most popul... NaN  60995
# 1  The film continues the story of teenage Billy ... NaN  98246
# 2  Cole falls head over heels for enigmatic Sadie... NaN  47509
# Enter the new column names, comma separated: 'Title', 'image_url', 'details_url', 'date', 'duration', 'genres', 'rating', 'metascore', 'summary', 'votes', 'gross'
# File: /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_1980_1981.csv
#                          0   \
# 0                  Brubaker
# 1              Best Friends
# 2  Friday the 13th Part III
#
#                                                   1                  2   \
# 0  https://m.media-amazon.com/images/S/sash/4Fyxw...  /title/tt0080474/
# 1  https://m.media-amazon.com/images/S/sash/4Fyxw...  /title/tt0083641/
# 2  https://m.media-amazon.com/images/S/sash/4Fyxw...  /title/tt0083972/
#
#        3        4                                     5    6   7   \
# 0  (1980)  131 min            \nCrime, Drama              7.1  54
# 1  (1982)  116 min  \nComedy, Drama, Romance              5.5  70
# 2  (1982)   95 min        \nHorror, Thriller              5.6  30
#
#                                                   8   9           10
# 0  The new warden of a small prison farm in Arkan... NaN  37,121,708
# 1  After five successful years of living and work... NaN  36,821,203
# 2  Jason Voorhees stalks a group of friends who's... NaN  36,690,067
# Enter the new column names, comma separated: 'Title', 'image_url', 'details_url', 'date', 'duration', 'genres', 'rating', 'metascore', 'summary', 'votes', 'gross'
# File: /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_1988_1989.csv
#               0                                                  1   \
# 0     Flatliners  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 1         Misery  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 2  Harlem Nights  https://m.media-amazon.com/images/S/sash/4Fyxw...
#
#                   2       3        4                                    5   \
# 0  /title/tt0099582/  (1990)  115 min  \nDrama, Horror, Sci-Fi
# 1  /title/tt0100157/  (1990)  107 min        \nDrama, Thriller
# 2  /title/tt0097481/  (1989)  116 min   \nComedy, Crime, Drama
#
#     6   7                                                  8   9           10
# 0  6.5  55  Five medical students experiment with "near de... NaN  61,490,000
# 1  7.8  75  After a famous author is rescued from a car cr... NaN  61,276,872
# 2  6.1  16  During the 1930s, a New York City illegal gamb... NaN  60,864,870
# Enter the new column names, comma separated: 'Title', 'image_url', 'details_url', 'date', 'duration', 'genres', 'rating', 'metascore', 'summary', 'votes', 'gross'
# File: /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_2008_2009.csv
#                                     0   \
# 0  Prince of Persia: The Sands of Time
# 1   High School Musical 3: Senior Year
# 2                   Madea Goes to Jail
#
#                                                   1                  2   \
# 0  https://m.media-amazon.com/images/S/sash/4Fyxw...  /title/tt0473075/
# 1  https://m.media-amazon.com/images/S/sash/4Fyxw...  /title/tt0962726/
# 2  https://m.media-amazon.com/images/S/sash/4Fyxw...  /title/tt1142800/
#
#        3        4                                         5    6   7   \
# 0  (2010)  116 min  \nAction, Adventure, Fantasy              6.6  50
# 1  (2008)  112 min       \nComedy, Drama, Family              4.9  57
# 2  (2009)  103 min        \nComedy, Crime, Drama              4.5  50
#
#                                                   8   9           10
# 0  A young fugitive prince and princess must stop... NaN  90,759,676
# 1  As seniors in high school, Troy and Gabriella ... NaN  90,559,416
# 2  Mischievous grandma Madea lands in jail, where... NaN  90,485,233
# Enter the new column names, comma separated: 'Title', 'image_url', 'details_url', 'date', 'duration', 'genres', 'rating', 'metascore', 'summary', 'votes', 'gross'
# File: /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_2018_2019.csv
#                                0   \
# 0  Dora and the Lost City of Gold
# 1                        Blockers
# 2           Pacific Rim: Uprising
#
#                                                   1                  2   \
# 0  https://m.media-amazon.com/images/S/sash/4Fyxw...  /title/tt7547410/
# 1  https://m.media-amazon.com/images/S/sash/4Fyxw...  /title/tt2531344/
# 2  https://m.media-amazon.com/images/S/sash/4Fyxw...  /title/tt2557478/
#
#        3        4                                         5    6   7   \
# 0  (2019)  102 min   \nAction, Adventure, Comedy              6.1  63
# 1  (2018)  102 min               \nComedy, Drama              6.2  69
# 2  (2018)  111 min  \nAction, Adventure, Fantasy              5.6  44
#
#                                                   8   9           10
# 0  Teenage explorer Dora leads her friends on an ... NaN  60,477,943
# 1  Three parents try to stop their daughters from... NaN  60,311,495
# 2  Jake Pentecost, son of Stacker Pentecost, reun... NaN  59,874,525
# Enter the new column names, comma separated: 'Title', 'image_url', 'details_url', 'date', 'duration', 'genres', 'rating', 'metascore', 'summary', 'votes', 'gross'

# %% [markdown]
# #### Compiling all the data into one csv

# %%
# Assuming csv_files is your list of csv file paths

# Loop through the CSV files and print the column names
for csv_file in csv_files:
    df = pd.read_csv(csv_file, nrows=0)
    print(f'Column names for {csv_file}: \n{df.columns.tolist()}\n')
# Out:
# Column names for /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_2014_2015.csv:
# ["'Title'", " 'image_url'", " 'details_url'", " 'date'", " 'duration'", " 'genres'", " 'rating'", " 'metascore'", " 'summary'", " 'votes'", " 'gross'"]
#
# Column names for /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_2002_2003.csv:
# ["'Title'", " 'image_url'", " 'details_url'", " 'date'", " 'duration'", " 'genres'", " 'rating'", " 'metascore'", " 'summary'", " 'votes'", " 'gross'"]
#
# Column names for /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_2016_2017.csv:
# ["'Title'", " 'image_url'", " 'details_url'", " 'date'", " 'duration'", " 'genres'", " 'rating'", " 'metascore'", " 'summary'", " 'votes'", " 'gross'"]
#
# Column names for /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_1992_1993.csv:
# ["'Title'", " 'image_url'", " 'details_url'", " 'date'", " 'duration'", " 'genres'", " 'rating'", " 'metascore'", " 'summary'", " 'votes'", " 'gross'"]
#
# Column names for /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_2012_2013.csv:
# ["'Title'", " 'image_url'", " 'details_url'", " 'date'", " 'duration'", " 'genres'", " 'rating'", " 'metascore'", " 'summary'", " 'votes'", " 'gross'"]
#
# Column names for /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_2004_2005.csv:
# ["'Title'", " 'image_url'", " 'details_url'", " 'date'", " 'duration'", " 'genres'", " 'rating'", " 'metascore'", " 'summary'", " 'votes'", " 'gross'"]
#
# Column names for /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_1996_1997.csv:
# ["'Title'", " 'image_url'", " 'details_url'", " 'date'", " 'duration'", " 'genres'", " 'rating'", " 'metascore'", " 'summary'", " 'votes'", " 'gross'"]
#
# Column names for /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_1998_1999.csv:
# ["'Title'", " 'image_url'", " 'details_url'", " 'date'", " 'duration'", " 'genres'", " 'rating'", " 'metascore'", " 'summary'", " 'votes'", " 'gross'"]
#
# Column names for /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_1982_1983.csv:
# ["'Title'", " 'image_url'", " 'details_url'", " 'date'", " 'duration'", " 'genres'", " 'rating'", " 'metascore'", " 'summary'", " 'votes'", " 'gross'"]
#
# Column names for /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_1986_1987.csv:
# ["'Title'", " 'image_url'", " 'details_url'", " 'date'", " 'duration'", " 'genres'", " 'rating'", " 'metascore'", " 'summary'", " 'votes'", " 'gross'"]
#
# Column names for /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_2006_2007.csv:
# ["'Title'", " 'image_url'", " 'details_url'", " 'date'", " 'duration'", " 'genres'", " 'rating'", " 'metascore'", " 'summary'", " 'votes'", " 'gross'"]
#
# Column names for /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_2000_2001.csv:
# ["'Title'", " 'image_url'", " 'details_url'", " 'date'", " 'duration'", " 'genres'", " 'rating'", " 'metascore'", " 'summary'", " 'votes'", " 'gross'"]
#
# Column names for /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_1994_1995.csv:
# ["'Title'", " 'image_url'", " 'details_url'", " 'date'", " 'duration'", " 'genres'", " 'rating'", " 'metascore'", " 'summary'", " 'votes'", " 'gross'"]
#
# Column names for /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_1990_1991.csv:
# ["'Title'", " 'image_url'", " 'details_url'", " 'date'", " 'duration'", " 'genres'", " 'rating'", " 'metascore'", " 'summary'", " 'votes'", " 'gross'"]
#
# Column names for /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_1984_1985.csv:
# ["'Title'", " 'image_url'", " 'details_url'", " 'date'", " 'duration'", " 'genres'", " 'rating'", " 'metascore'", " 'summary'", " 'votes'", " 'gross'"]
#
# Column names for /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_2010_2011.csv:
# ["'Title'", " 'image_url'", " 'details_url'", " 'date'", " 'duration'", " 'genres'", " 'rating'", " 'metascore'", " 'summary'", " 'votes'", " 'gross'"]
#
# Column names for /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_2022_2023.csv:
# ["'Title'", " 'image_url'", " 'details_url'", " 'date'", " 'duration'", " 'genres'", " 'rating'", " 'metascore'", " 'summary'", " 'votes'", " 'gross'"]
#
# Column names for /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_1980_1981.csv:
# ["'Title'", " 'image_url'", " 'details_url'", " 'date'", " 'duration'", " 'genres'", " 'rating'", " 'metascore'", " 'summary'", " 'votes'", " 'gross'"]
#
# Column names for /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_1988_1989.csv:
# ["'Title'", " 'image_url'", " 'details_url'", " 'date'", " 'duration'", " 'genres'", " 'rating'", " 'metascore'", " 'summary'", " 'votes'", " 'gross'"]
#
# Column names for /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_2008_2009.csv:
# ["'Title'", " 'image_url'", " 'details_url'", " 'date'", " 'duration'", " 'genres'", " 'rating'", " 'metascore'", " 'summary'", " 'votes'", " 'gross'"]
#
# Column names for /content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/movies_2018_2019.csv:
# ["'Title'", " 'image_url'", " 'details_url'", " 'date'", " 'duration'", " 'genres'", " 'rating'", " 'metascore'", " 'summary'", " 'votes'", " 'gross'"]

# %%
# Define the column names
column_names = ['Title', 'image_url', 'details_url', 'date', 'duration', 'genres', 'rating', 'metascore', 'summary', 'votes', 'gross']

# %%
all_data = pd.DataFrame()

# %%
# Loop through the CSV files and read each one into a dataframe
for csv_file in csv_files:
    df = pd.read_csv(csv_file)
    all_data = pd.concat([all_data, df], ignore_index=True)

# %%
all_data.shape
# Out:
# (21855, 11)

# %%
all_data.columns = all_data.columns.str.strip(' \'')

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21855 entries, 0 to 21854
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Title        21855 non-null  object
#  1   image_url    21855 non-null  object
#  2   details_url  21855 non-null  object
#  3   date         21855 non-null  object
#  4   duration     21284 non-null  object
#  5   genres       21711 non-null  object
#  6   rating       21855 non-null  float64
#  7   metascore    10626 non-null  float64
#  8   summary      21359 non-null  object
#  9   votes        0 non-null      float64
#  10  gross        21855 non-null  object
# dtypes: float64(3), object(8)
# memory usage: 1.8+ MB

# %%
# Remove trailing apostrophe from column names
all_data.columns = all_data.columns.str.rstrip('\'')

# Replace NaN values in 'gross' column with 999999999999
all_data['gross'].fillna(999999999999, inplace=True)

# Remove commas and convert 'gross' column to integer
all_data['gross'] = all_data['gross'].str.replace(',', '').astype(float)

# Sort the dataframe by 'gross' column in descending order
all_data.sort_values('gross', ascending=False, inplace=True)

all_data
# Out:
#                                             Title  \
# 13449                             The Dark Knight
# 13450  Pirates of the Caribbean: Dead Man's Chest
# 13451                                Spider-Man 3
# 13452                             Shrek the Third
# 13453                                Transformers
# ...                                           ...
# 19050                                   Fireheart
# 19051                   Late Night with the Devil
# 19052                              Alone Together
# 19053                                   Real Love
# 19054                             End of the Road
#
#                                                image_url         details_url  \
# 13449  https://m.media-amazon.com/images/S/sash/4Fyxw...   /title/tt0468569/
# 13450  https://m.media-amazon.com/images/S/sash/4Fyxw...   /title/tt0383574/
# 13451  https://m.media-amazon.com/images/S/sash/4Fyxw...   /title/tt0413300/
# 13452  https://m.media-amazon.com/images/S/sash/4Fyxw...   /title/tt0413267/
# 13453  https://m.media-amazon.com/images/S/sash/4Fyxw...   /title/tt0418279/
# ...                                                  ...                 ...
# 19050  https://m.media-amazon.com/images/S/sash/4Fyxw...   /title/tt8354218/
# 19051  https://m.media-amazon.com/images/S/sash/4Fyxw...  /title/tt14966898/
# 19052  https://m.media-amazon.com/images/S/sash/4Fyxw...  /title/tt14584284/
# 19053  https://m.media-amazon.com/images/S/sash/4Fyxw...  /title/tt27230149/
# 19054  https://m.media-amazon.com/images/S/sash/4Fyxw...  /title/tt13655328/
#
#               date duration                                      genres  \
# 13449       (2008)  152 min          \nAction, Crime, Drama
# 13450       (2006)  151 min    \nAction, Adventure, Fantasy
# 13451       (2007)  139 min     \nAction, Adventure, Sci-Fi
# 13452       (2007)   93 min  \nAnimation, Adventure, Comedy
# 13453       (2007)  144 min     \nAction, Adventure, Sci-Fi
# ...            ...      ...                                         ...
# 19050       (2022)   92 min  \nAnimation, Adventure, Comedy
# 19051       (2023)   86 min                        \nHorror
# 19052   (I) (2022)   98 min                \nDrama, Romance
# 19053  (II) (2023)   87 min                \nDrama, Romance
# 19054  (II) (2022)   89 min          \nAction, Crime, Drama
#
#        rating  metascore                                            summary  \
# 13449     9.0       84.0  When the menace known as the Joker wreaks havo...
# 13450     7.3       53.0  Jack Sparrow races to recover the heart of Dav...
# 13451     6.3       59.0  A strange black entity from another world bond...
# 13452     6.1       58.0  Reluctantly designated as the heir to the land...
# 13453     7.0       61.0  An ancient struggle between two Cybertronian r...
# ...       ...        ...                                                ...
# 19050     6.2        NaN  Sixteen-year-old Georgia Nolan dreams of being...
# 19051     8.3       71.0  A live television broadcast in 1977 goes horri...
# 19052     5.4       52.0  Two strangers embroiled in bad relationships w...
# 19053     7.4        NaN  It follows Kendra as she goes to an HBCU in No...
# 19054     4.8       44.0  In this high-octane action thriller, a cross-c...
#
#        votes        gross
# 13449    NaN  534858444.0
# 13450    NaN  423315812.0
# 13451    NaN  336530303.0
# 13452    NaN  320706665.0
# 13453    NaN  319246193.0
# ...      ...          ...
# 19050    NaN          NaN
# 19051    NaN          NaN
# 19052    NaN          NaN
# 19053    NaN          NaN
# 19054    NaN          NaN
#
# [21855 rows x 11 columns]

# %%
all_data.reset_index(drop=True, inplace=True)

# %%
all_data
# Out:
#                                             Title  \
# 0                                 The Dark Knight
# 1      Pirates of the Caribbean: Dead Man's Chest
# 2                                    Spider-Man 3
# 3                                 Shrek the Third
# 4                                    Transformers
# ...                                           ...
# 21850                                   Fireheart
# 21851                   Late Night with the Devil
# 21852                              Alone Together
# 21853                                   Real Love
# 21854                             End of the Road
#
#                                                image_url         details_url  \
# 0      https://m.media-amazon.com/images/S/sash/4Fyxw...   /title/tt0468569/
# 1      https://m.media-amazon.com/images/S/sash/4Fyxw...   /title/tt0383574/
# 2      https://m.media-amazon.com/images/S/sash/4Fyxw...   /title/tt0413300/
# 3      https://m.media-amazon.com/images/S/sash/4Fyxw...   /title/tt0413267/
# 4      https://m.media-amazon.com/images/S/sash/4Fyxw...   /title/tt0418279/
# ...                                                  ...                 ...
# 21850  https://m.media-amazon.com/images/S/sash/4Fyxw...   /title/tt8354218/
# 21851  https://m.media-amazon.com/images/S/sash/4Fyxw...  /title/tt14966898/
# 21852  https://m.media-amazon.com/images/S/sash/4Fyxw...  /title/tt14584284/
# 21853  https://m.media-amazon.com/images/S/sash/4Fyxw...  /title/tt27230149/
# 21854  https://m.media-amazon.com/images/S/sash/4Fyxw...  /title/tt13655328/
#
#               date duration                                      genres  \
# 0           (2008)  152 min          \nAction, Crime, Drama
# 1           (2006)  151 min    \nAction, Adventure, Fantasy
# 2           (2007)  139 min     \nAction, Adventure, Sci-Fi
# 3           (2007)   93 min  \nAnimation, Adventure, Comedy
# 4           (2007)  144 min     \nAction, Adventure, Sci-Fi
# ...            ...      ...                                         ...
# 21850       (2022)   92 min  \nAnimation, Adventure, Comedy
# 21851       (2023)   86 min                        \nHorror
# 21852   (I) (2022)   98 min                \nDrama, Romance
# 21853  (II) (2023)   87 min                \nDrama, Romance
# 21854  (II) (2022)   89 min          \nAction, Crime, Drama
#
#        rating  metascore                                            summary  \
# 0         9.0       84.0  When the menace known as the Joker wreaks havo...
# 1         7.3       53.0  Jack Sparrow races to recover the heart of Dav...
# 2         6.3       59.0  A strange black entity from another world bond...
# 3         6.1       58.0  Reluctantly designated as the heir to the land...
# 4         7.0       61.0  An ancient struggle between two Cybertronian r...
# ...       ...        ...                                                ...
# 21850     6.2        NaN  Sixteen-year-old Georgia Nolan dreams of being...
# 21851     8.3       71.0  A live television broadcast in 1977 goes horri...
# 21852     5.4       52.0  Two strangers embroiled in bad relationships w...
# 21853     7.4        NaN  It follows Kendra as she goes to an HBCU in No...
# 21854     4.8       44.0  In this high-octane action thriller, a cross-c...
#
#        votes        gross
# 0        NaN  534858444.0
# 1        NaN  423315812.0
# 2        NaN  336530303.0
# 3        NaN  320706665.0
# 4        NaN  319246193.0
# ...      ...          ...
# 21850    NaN          NaN
# 21851    NaN          NaN
# 21852    NaN          NaN
# 21853    NaN          NaN
# 21854    NaN          NaN
#
# [21855 rows x 11 columns]

# %%
#That's strange, time to find the really top grossing movies like Avatar and Avengers

# %%
# Write the concatenated dataframe to a new CSV file
all_data.to_csv('/content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/all_movie_ids_final.csv', index=False)

# %% [markdown]
# ## Okay! It's done! Now for the next step: Scraping ALL the important details, except for the actual user reviews:

# %%
# %cd /content/drive/MyDrive/IMDB\ Project/Scraping
# !scrapy startproject ScraPy_Code_2
# Out:
# /content/drive/MyDrive/IMDB Project/Scraping
# New Scrapy project 'ScraPy_Code_2', using template directory '/usr/local/lib/python3.10/dist-packages/scrapy/templates/project', created in:
#     /content/drive/MyDrive/IMDB Project/Scraping/ScraPy_Code_2
#
# You can start your first spider with:
#     cd ScraPy_Code_2
#     scrapy genspider example example.com

# %%
# %cd /content/drive/MyDrive/IMDB\ Project/Scraping/ScraPy_Code_2/ScraPy_Code_2/spiders
# Out:
# /content/drive/MyDrive/IMDB Project/Scraping/ScraPy_Code_2/ScraPy_Code_2/spiders

# %%
# %%writefile more_details_scraper.py

import pandas as pd
import scrapy
import datetime
import json
import os
from scrapy import signals
import csv


class csv_dialect(csv.Dialect):
    delimiter = ','
    quotechar = '"'
    doublequote = True
    skipinitialspace = False
    lineterminator = '\n'
    quoting = csv.QUOTE_ALL


class IMDbSpider(scrapy.Spider):
    name = 'scraping_test2'
    user_agent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
    output_directory = '/content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_2.2_data'
    os.makedirs(output_directory, exist_ok=True)
    data = []

    # Try to read in the already scraped titles
    try:
        df_scraped = pd.read_csv('/content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_2.2_data/more_details.csv', header=None)
    except pd.errors.EmptyDataError:
        # If the file is empty, create an empty DataFrame
        df_scraped = pd.DataFrame()

    scraped_ids = df_scraped[0].tolist() if not df_scraped.empty else []

    # Read in the start URLs and remove already scraped titles
    df = pd.read_csv('/content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data/all_movie_ids_final.csv')
    df['details_url'] = 'https://www.imdb.com' + df['details_url']
    df['id'] = df['details_url'].str.extract(r'(tt\d+)')
    df = df[~df['id'].isin(scraped_ids)]
    start_urls = df['details_url'].tolist()

    # Record the start time
    start_time = datetime.datetime.now()

    # Initialize a counter
    url_count = 0

    def handle_error(self, failure):
        self.log(failure)

    def start_requests(self):
        for url in self.start_urls:
            imdb_id = url.split('/')[-2]
            output_file = os.path.join(self.output_directory, 'more_details_2.csv')
            yield scrapy.Request(url, headers={'User-Agent': self.user_agent}, meta={'imdb_id': imdb_id}, errback=self.handle_error, callback=self.parse)

    def parse(self, response):
        imdb_id = response.meta['imdb_id']


        # Increment the counter
        self.url_count += 1



        # Calculate the elapsed time and the average time per item
        elapsed_time = datetime.datetime.now() - self.start_time
        avg_time_per_item = elapsed_time / self.url_count

        # Estimate the remaining time
        remaining_items = len(self.start_urls) - self.url_count
        estimated_remaining_time = avg_time_per_item * remaining_items

        self.log(f'***********************TIME ESTIMATION ********************************* \n\n Processing {imdb_id} ({self.url_count}/{len(self.start_urls)}), estimated remaining time: {estimated_remaining_time}\n\n')




        # Initialize the meta dictionary with the imdb_id
        meta = {
            'imdb_id': imdb_id
        }
    #START OF PARSING CODE HERE
    #Scraping Main Details
        title = response.css('h1.sc-afe43def-0 span.sc-afe43def-1::text').get()
        director = response.css('li[data-testid="title-pc-principal-credit"] span:contains("Director") ~ div ul li a::text').get()
        writers = response.css('li[data-testid="title-pc-principal-credit"] span:contains("Writers") ~ div ul li a::text').getall()
        stars = response.css('li[data-testid="title-pc-principal-credit"] a:contains("Stars") ~ div ul li a::text').getall()
        user_reviews = response.css('ul[data-testid="reviewContent-all-reviews"] a:contains("User reviews") span.score::text').get()
        critic_reviews = response.css('ul[data-testid="reviewContent-all-reviews"] a:contains("Critic reviews") span.score::text').get()
        metascore = response.css('ul[data-testid="reviewContent-all-reviews"] a:contains("Metascore") span.score-meta::text').get()

    # Scraping Technical Specs
        tech_specs = response.css('div[data-testid="title-techspecs-section"]')
        runtime = tech_specs.css('li[data-testid="title-techspec_runtime"] div.ipc-metadata-list-item__content-container::text').getall()
        runtime = " ".join(runtime)  # Joining the scraped parts to form the complete runtime text
        sound_mix = tech_specs.css('li[data-testid="title-techspec_soundmix"] a::text').getall()
        # Scraping aspect ratio
        aspect_ratio = tech_specs.css('span.ipc-metadata-list-item__list-content-item::text').get()
    # Scraping Box Office Information
        budget = response.css('li[data-testid="title-boxoffice-budget"] span.ipc-metadata-list-item__list-content-item::text').get()
        gross_us_canada = response.css('li[data-testid="title-boxoffice-grossdomestic"] span.ipc-metadata-list-item__list-content-item::text').get()

        #
        opening_weekend_data = response.css('li[data-testid="title-boxoffice-openingweekenddomestic"] span.ipc-metadata-list-item__list-content-item::text').getall()
        if opening_weekend_data:
            opening_weekend_amount = opening_weekend_data[0]
            opening_weekend_date = opening_weekend_data[1] if len(opening_weekend_data) > 1 else None
        else:
            opening_weekend_amount = None
            opening_weekend_date = None
        #



        # opening_weekend_amount = response.css('li[data-testid="title-boxoffice-openingweekenddomestic"] span.ipc-metadata-list-item__list-content-item::text').getall()[0]
        # opening_weekend_date = response.css('li[data-testid="title-boxoffice-openingweekenddomestic"] span.ipc-metadata-list-item__list-content-item::text').getall()[1]
        opening_weekend_us_canada = f"{opening_weekend_amount}, {opening_weekend_date}"
        gross_worldwide = response.css('li[data-testid="title-boxoffice-cumulativeworldwidegross"] span.ipc-metadata-list-item__list-content-item::text').get()

    # Scraping Details Section
        release_date = response.css('li[data-testid="title-details-releasedate"] a.ipc-metadata-list-item__list-content-item--link::text').get()
        countries_of_origin = response.css('li[data-testid="title-details-origin"] a.ipc-metadata-list-item__list-content-item--link::text').getall()
        official_sites = response.css('li[data-testid="details-officialsites"] a.ipc-metadata-list-item__list-content-item--link::attr(href)').getall()
        languages = response.css('li[data-testid="title-details-languages"] a.ipc-metadata-list-item__list-content-item--link::text').getall()
        also_known_as = response.css('li[data-testid="title-details-akas"] span.ipc-metadata-list-item__list-content-item::text').get()
        filming_locations = response.css('li[data-testid="title-details-filminglocations"] a.ipc-metadata-list-item__list-content-item--link::text').get()
        production_companies = response.css('li[data-testid="title-details-companies"] a.ipc-metadata-list-item__list-content-item--link::text').getall()


        # Update the meta dictionary with new data
        meta.update({
            'title': title,
            'runtime': runtime,
            'sound_mix': sound_mix,
            'aspect_ratio': aspect_ratio,
            'budget': budget,
            'gross_us_canada': gross_us_canada,
            'opening_weekend_us_canada': opening_weekend_us_canada,
            'gross_worldwide': gross_worldwide,
            'writers': writers,
            'release_date': release_date,
            'countries_of_origin': countries_of_origin,
            'official_sites': official_sites,
            'director': director,
            'writers': writers,
            'stars': stars,
            'user_reviews': user_reviews,
            'critic_reviews': critic_reviews,
            'metascore': metascore,
            'languages': languages,
            'also_known_as': also_known_as,
            'filming_locations': filming_locations,
            'production_companies': production_companies
        })


        print(f'Title: {title}')
        print(f'Director: {director}')

        yield response.follow(f'https://www.imdb.com/title/{imdb_id}/plotsummary', self.parse_plot_summary, meta=meta, errback=self.handle_error)

    def parse_plot_summary(self, response):
        imdb_id = response.meta['imdb_id']

        # Scraping plot summaries
        plot_summaries = response.css('div[data-testid="sub-section-summaries"] div.ipc-html-content-inner-div::text').getall()
        # Scraping synopsis
        synopsis = response.css('ul.meta-data-list-full div.ipc-html-content-inner-div::text').get()



        # Update the meta dictionary with new data
        response.meta.update({
            'plot_summaries': plot_summaries,
            'synopsis': synopsis
        })


        yield response.follow(f'https://www.imdb.com/title/{imdb_id}/reviews?ref_=tt_urv', self.parse_user_reviews, meta=response.meta, errback=self.handle_error)


    def parse_user_reviews(self, response):
        imdb_id = response.meta['imdb_id']
        review_blocks = response.css('.review-container')

        if not review_blocks:
            print("No review blocks found.")
            print("Going to Technical Specs")
            yield response.follow(f'https://www.imdb.com/title/{imdb_id}/technical/?ref_=tt_spec_sm',
                                self.parse_technical_specs,
                                meta=response.meta,
                                errback=self.handle_error)

        # Get reviews_data from response.meta, if it doesn't exist initialize it as an empty list
        reviews_data_str = response.meta.get('reviews_data', '[]')
        # Convert the string back to a list
        reviews_data_list = eval(reviews_data_str)
        reviewer_ratings = response.meta.get('reviewer_ratings', [])

        for block in review_blocks:
            review = block.css('.text.show-more__control::text').get()
            reviewer = block.css('.display-name-link a::text').get()
            rating = block.css('.ipl-ratings-bar span.rating-other-user-rating span::text').get()

            print(f"Reviewer: {reviewer}, Rating: {rating}")

            review_data = {  # dictionary to hold individual review data
                'review': review,
                'reviewer': reviewer,
                'rating': rating
            }

            reviews_data_list.append(str(review_data))  # append string representation of review_data dictionary to reviews_data_list

            reviewer_ratings.append({
                'reviewer': reviewer,
                'rating': rating
            })

        # Convert the list back to a string to store it in response.meta
        reviews_data_str = str(reviews_data_list)

        response.meta.update({
            'reviews_data': reviews_data_str,  # Update with the string representation of the list
            'reviewer_ratings': reviewer_ratings
        })

        key = response.css('.load-more-data::attr(data-key)').get()

        # ... rest of your code


        print(f"Key: {key}")

        if key:
            yield scrapy.Request(
                url = f'https://www.imdb.com/title/{imdb_id}/reviews/_ajax?ref_=undefined&paginationKey='+ key,
                callback=self.parse_user_reviews,
                meta=response.meta,
            )
        else:
            print("No key found.")
            yield response.follow(f'https://www.imdb.com/title/{imdb_id}/technical/?ref_=tt_spec_sm',
                                self.parse_technical_specs,
                                meta=response.meta,
                                errback=self.handle_error)

    def parse_technical_specs(self, response):
        imdb_id = response.meta['imdb_id']

        # Scraping Technical Specs
        runtime = response.css('li#runtime span.ipc-metadata-list-item__list-content-item::text').getall()
        sound_mix = response.css('li#soundmixes a.ipc-metadata-list-item__list-content-item--link::text').getall()
        color = response.css('li#colorations a.ipc-metadata-list-item__list-content-item--link::text').getall()
        aspect_ratio = response.css('li#aspectratio span.ipc-metadata-list-item__list-content-item::text').getall()
        camera = response.css('li#cameras span.ipc-metadata-list-item__list-content-item::text').getall()
        laboratory = response.css('li#laboratory span.ipc-metadata-list-item__list-content-item::text').getall()
        film_length = response.css('li#filmLength span.ipc-metadata-list-item__list-content-item::text').getall()
        negative_format = response.css('li#negativeFormat span.ipc-metadata-list-item__list-content-item::text').getall()
        cinematographic_process = response.css('li#process span.ipc-metadata-list-item__list-content-item::text').getall()
        printed_film_format = response.css('li#printedFormat span.ipc-metadata-list-item__list-content-item::text').getall()



        # Update the meta dictionary with new data
        response.meta.update({
            'runtime': runtime,
            'sound_mix': sound_mix,
            'color': color,
            'aspect_ratio': aspect_ratio,
            'camera': camera,
            'laboratory': laboratory,
            'film_length': film_length,
            'negative_format': negative_format,
            'cinematographic_process': cinematographic_process,
            'printed_film_format': printed_film_format
        })

        yield response.follow(f'https://www.imdb.com/title/{imdb_id}/externalreviews?ref_=tt_ov_rt', self.parse_external_reviews, meta=response.meta, errback=self.handle_error)

    def parse_external_reviews(self, response):
        imdb_id = response.meta['imdb_id']

        # Locate all review site blocks
        review_site_blocks = response.css('.ipc-metadata-list__item.ipc-metadata-list-item--link')

        # Lists to store review site names and URLs
        review_site_names = []
        review_site_urls = []

        # For each block, extract the reviewer site name and URL
        for block in review_site_blocks:
            review_site_name = block.css('a.ipc-metadata-list-item__label--link::text').get()
            review_site_url = block.css('a.ipc-metadata-list-item__label--link::attr(href)').get()

            # Add reviewer site name to the list
            review_site_names.append(review_site_name)

            # Add reviewer site URL to the list
            review_site_urls.append(review_site_url)

        # Update the meta dictionary with new data
        response.meta.update({
            'review_site_names': review_site_names,
            'review_site_urls': review_site_urls
        })


        # Convert the meta dictionary to a DataFrame
        meta_df = pd.DataFrame([response.meta])

        # Write to CSV file
        output_file = os.path.join(self.output_directory, '/content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_2.2_data/more_details.csv')
        print(f"Writing data to {output_file}")  # Print the file path
        print(meta_df)  # Print the data that is being written
        meta_df.to_csv(output_file, mode='a', header=False, index=False, encoding='utf-8')

        # Yielding the scraped data
        yield response.meta

    def handle_error(self, failure):
        # Log all failures
        self.log(failure)
        # Yield the meta data
        yield failure.request.meta
# Out:
# Overwriting more_details_scraper.py

# %% [markdown]
# ## Part 2 Execution

# %% [markdown]
# This is where the magic happens! This code will run the above spider, and you'll get to see from the output what items has been scraped, what hasn't, etc.
#
# The important thing to note is that this ScraPy spider is tuned specifically to scrape certain details of movies from IMDb, filtered based on the previously collected list in part 1!

# %%
# Navigate to the spiders folder to view the spider codes
# %cd /content/drive/MyDrive/IMDB\ Project/Scraping/ScraPy_Code_2/ScraPy_Code_2/spiders
# !ls
# Out:
# /content/drive/MyDrive/IMDB Project/Scraping/ScraPy_Code_2/ScraPy_Code_2/spiders
# __init__.py  more_details.csv  more_details_scraper.py	__pycache__

# %%
#Now to actually run the spider! The data will be saved  in '/content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_1_data'

# %cd /content/drive/MyDrive/IMDB\ Project/Scraping/ScraPy_Code_2/ScraPy_Code_2/spiders

# !scrapy runspider more_details_scraper.py
# Out:
# /content/drive/MyDrive/IMDB Project/Scraping/ScraPy_Code_2/ScraPy_Code_2/spiders
# Traceback (most recent call last):
#   File "/usr/local/bin/scrapy", line 8, in <module>
#     sys.exit(execute())
#   File "/usr/local/lib/python3.10/dist-packages/scrapy/cmdline.py", line 157, in execute
#     cmd.crawler_process = CrawlerProcess(settings)
#   File "/usr/local/lib/python3.10/dist-packages/scrapy/crawler.py", line 325, in __init__
#     super().__init__(settings)
#   File "/usr/local/lib/python3.10/dist-packages/scrapy/crawler.py", line 197, in __init__
#     self.spider_loader = self._get_spider_loader(settings)
#   File "/usr/local/lib/python3.10/dist-packages/scrapy/crawler.py", line 191, in _get_spider_loader
#     return loader_cls.from_settings(settings.frozencopy())
#   File "/usr/local/lib/python3.10/dist-packages/scrapy/spiderloader.py", line 69, in from_settings
#     return cls(settings)
#   File "/usr/local/lib/python3.10/dist-packages/scrapy/spiderloader.py", line 24, in __init__
#     self._load_all_spiders()
#   File "/usr/local/lib/python3.10/dist-packages/scrapy/spiderloader.py", line 53, in _load_all_spiders
#     for module in walk_modules(name):
#   File "/usr/local/lib/python3.10/dist-packages/scrapy/utils/misc.py", line 92, in walk_modules
#     submod = import_module(fullpath)
#   File "/usr/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1006, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/content/drive/MyDrive/IMDB Project/Scraping/ScraPy_Code_2/ScraPy_Code_2/spiders/more_details_scraper.py", line 20, in <module>
#     class IMDbSpider(scrapy.Spider):
#   File "/content/drive/MyDrive/IMDB Project/Scraping/ScraPy_Code_2/ScraPy_Code_2/spiders/more_details_scraper.py", line 29, in IMDbSpider
#     df_scraped = pd.read_csv('/content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_2.2_data/more_details.csv', header=None)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py", line 211, in wrapper
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py", line 331, in wrapper
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py", line 950, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py", line 611, in _read
#     return parser.read(nrows)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py", line 1778, in read
#     ) = self._engine.read(  # type: ignore[attr-defined]
#   File "/usr/local/lib/python3.10/dist-packages/pandas/io/parsers/c_parser_wrapper.py", line 230, in read
#     chunks = self._reader.read_low_memory(nrows)
#   File "pandas/_libs/parsers.pyx", line 808, in pandas._libs.parsers.TextReader.read_low_memory
#   File "pandas/_libs/parsers.pyx", line 866, in pandas._libs.parsers.TextReader._read_rows
#   File "pandas/_libs/parsers.pyx", line 852, in pandas._libs.parsers.TextReader._tokenize_rows
#   File "pandas/_libs/parsers.pyx", line 1973, in pandas._libs.parsers.raise_parser_error
# pandas.errors.ParserError: Error tokenizing data. C error: Expected 41 fields in line 65545, saw 43

# %% [markdown]
# In case you're wondering what this insanely long wall of text means, and why its continously moving, allow me to explain:
#
# >`Processing tt2293003 (473/57619), estimated remaining time: 3 days, 5:06:39.038536`
#
#
# Gives you an idea of how many more items in the list there is to be scraped. Note that the total amount is slightly different considering that your file might already have some movie titles in there
#
#
# > `Key:g4w6ddbmqyzdo6ic4oxwjnbuqpu44cj734kdv4pkb3d7ev35pjt6uds7ou4vvmjcb4dtjnwhi66hz34nvubrcdjplm2jo`
#
#
#
# Is part of the scrapy code output where it is extracting the AJAX key from the 'load more' button, to request from the server the next 50 user reviews.
#
#
# >`2023-07-19 12:20:31 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt3393786/reviews?ref_=tt_urv> (referer: https://www.imdb.com/title/tt3393786/plotsummary/)`
#
# Simply means that the spider has successfully crawled through the abovementioned URL and is now going towards the next part of the title details (in this case it's going to the reviews page)

# %% [markdown]
# Here is the code below to run in case some of the scraped data is wrong, or in the incorrect format, so that those lines will be removed and saved to a different file for cleaning later

# %%
import pandas as pd

# Load the dataframe
filename = '/content/drive/MyDrive/IMDB Project/Scraping/scraped_data/ScraPy_Code_2.2_data/more_details.csv'
df = pd.read_csv(filename, on_bad_lines='skip')

# Save the dataframe
df.to_csv(filename, index=False)
